# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# False

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are acting as a multidisciplinary advisory panel (climatologist, urban planner, economist, civil engineer, public health expert, and ethicist) for a coastal city of 1,000,000 residents with median income 20% below the national average, existing flood defenses rated as "moderate," and a municipal budget constraint such that adaptation spending cannot exceed 10% of current city GDP per decade; sea-level rise projections for 2100 are uncertain but modeled as three scenarios (low 0.6 m, mid 1.2 m, high 2.0 m). Produce a complete 50-year adaptation strategy that: (a) prioritizes interventions (structural, policy, social programs, and nature-based solutions) with justification for sequencing; (b) provides a decade-by-decade timeline with specific triggers tied to observable metrics (e.g., frequency of nuisance flooding, shoreline retreat rate, insurance cost increases) that move the plan from soft to hard interventions; (c) allocates a plausible portion of the constrained budget across interventions and sectors, explaining trade-offs; (d) projects expected outcomes (estimated lives saved, economic losses avoided, and changes in inequality measures) under each sea-level scenario; (e) identifies the three most important scientific, economic, or social uncertainties, and gives a prioritized, realistic plan to reduce those uncertainties; (f) supplies three concrete monitoring metrics and thresholds for changing strategy; and (g) lists three ethically contentious decisions you would make (e.g., managed retreat, differential investment by neighborhood), explains why you chose them over alternatives, and outlines how you would communicate and mitigate the harms. Finally, critique your own strategy by naming three plausible failure modes, the earliest warning signs for each, and specific contingency actions to correct course.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a complete 50-year adaptation strategy for a coastal city of 1,000,000 residents, with median income about 20% below the national average, currently "moderate" flood defenses, and a constraint that adaptation spending cannot exceed 10% of current city GDP per decade. Sea-level rise (SLR) by 2100 is uncertain and modeled with three scenarios: low 0.6 m, mid 1.2 m, high 2.0 m.
#
# Key assumptions (to keep the strategy concrete)
# - City GDP (current): about $75B/year. Adaptation spending ceiling: up to $7.5B per decade (10% of annual GDP, applied per-decade planning horizon).
# - Population and vulnerability: 1,000,000 residents; a substantial fraction of low-to-moderate income households live in neighborhoods exposed to nuisance flooding, drainage constraints, and shoreline retreat.
# - Existing defenses: “moderate” performance; some gates, embankments, and drainage networks that work under current loads but are stressed with higher water levels and more frequent Overtopping events.
# - Baseline hazard without adaptation: increasing nuisance flooding, groundwater rise, and occasional major storm surge events; direct annual economic losses and potential fatalities are non-negligible and rise with SLR.
# - Discount rate and time preference: standard municipal planning conventions (moderate discount rate, long-run geographies).
#
# (a) Priorities and sequencing of interventions (structural, policy, social programs, nature-based solutions) with justification
# Overarching sequencing principle: start with low-cost, high-visibility, high-leverage soft interventions that reduce risk quickly, build legitimacy, and protect vulnerable populations; progressively layer on nature-based and structural measures as data accumulate; reserve the most expensive, hard infrastructure for when triggers indicate necessity. This minimizes risk of stranded assets and respects equity constraints.
#
# 1) Soft wins in the near term (Years 1–5)
# - Policy and planning
#   - Update land-use plans to minimize new development in high-risk zones; strengthen building codes for flood resilience (e.g., elevated foundations, floodproofing, watertight envelopes).
#   - Adopt performance-based flood insurance subsidies tied to resilient retrofits; expand a city resilience fund and create a simple, transparent buyout/relocation framework for the most exposed properties.
#   - Enable “managed retreat” options as a voluntary, supportive pathway (no forced relocation) with fair compensation and moving assistance.
# - Social protection and equity
#   - Expand affordable housing near lower-risk areas; provide targeted grants for at-risk households to elevate utilities and critical systems (electric, water, sewer), and to retrofit homes.
#   - Establish a city-wide early warning system, community flood-alert drills, and neighborhood-level emergency response teams; prioritize low-income communities.
# - Nature-based solutions (NBIs) with fast-install potential
#   - Restore and expand blue-green corridors: wetlands restoration, living shorelines, mangroves (where applicable), and dune systems in amenity-rich and key flood-prone corridors.
#   - Implement green infrastructure in urban cores (bioswales, porous pavements, tree canopies, rooftop gardens) to reduce surface runoff and urban heat island effects that intensify flood impacts.
# - Insurance and finance
#   - Create or expand an affordable-resilience insurance program, with subsidized premiums for properties that adopt prescribed retrofit standards.
# - Monitoring and learning
#   - Install a dedicated resilience data platform to track performance, costs, and social outcomes; publish annual progress reports to maintain accountability.
#
# 2) Early modification of risk surface and targeted hardening (Years 6–15)
# - Policy and planning
#   - Implement spatially explicit risk zoning with credible buyout corridors for the most exposed blocks; begin strategic relocation in the highest-risk neighborhoods if supported by community engagement.
#   - Update local permit review thresholds to require flood-resilience retrofits for existing buildings in hazard zones.
# - NBIs and green-gray hybrids
#   - Scale up nature-based defense: multi-purpose marsh restoration, living shorelines on critical waterfront interfaces, and coastal dune system restoration in front of key neighborhoods and public assets.
# - Social programs
#   - Expand affordable home elevation subsidies and microgrants for risk-reducing upgrades; expand training programs to create local jobs in resilience projects.
# - Structural elements (pilot scale)
#   - Install modular, scalable stormwater pumps and gravity drainage improvements in selected flood-prone districts; pilot sea barriers only in areas with demonstrated exposure and community buy-in.
#
# 3) Strategic escalation to structural defense (Years 16–30)
# - Structural defense
#   - Based on triggers (see section b), begin large-scale flood defenses in the most exposed corridors: flood walls, surge barriers, strengthened levees, and upstream drainage enhancements to reduce backflow and overtopping.
# - NBIs and urban design
#   - Continue to expand NBIs, focusing on living shoreline continuity, restored wetlands, and integrated green roofs across the city’s neighborhoods to reduce energy, flooding, and heat exposure simultaneously.
# - Social programs and policy
#   - Scale buyouts/relocation programs with clear, community-driven criteria; ensure that vulnerable populations are not disproportionately displaced; ensure housing alternatives that preserve access to jobs and services.
# - Evaluation and maintenance planning
#   - Create formal maintenance plans and reserve funds for NBIs, urban green infrastructure, and structural defenses; integrate long-term asset management planning.
#
# 4) Full-scale resilience and adaptive governance (Years 31–50)
# - Structural and multi-layer defenses
#   - Implement high-capacity, multi-layer defenses in the most exposed corridors where risk remains high after NBIs; this includes tide gates, larger-scale flood barriers, and comprehensive drainage networks designed for current and projected loads.
# - Social protection and equity programs
#   - Institutionalize ongoing risk-sharing programs, targeted subsidies, and community-led adaptation planning; ensure that resilience benefits and costs are equitably distributed.
# - Nature-based stabilization and restoration
#   - Achieve a broad network of NBIs that provide flood protection, biodiversity benefits, coastal protection, and recreational value; maintain and expand green corridors city-wide.
# - Governance and finance
#   - Establish a long-term resilience bond program, with explicit use of proceeds for NBIs, housing resilience, and hazard mitigation; ensure transparency and citizen oversight.
#
# (b) Decade-by-decade timeline with triggers tied to observable metrics
# The triggers are designed to shift the plan gradually from soft to hard interventions as risk exposure grows or remains elevated. Triggers rely on observable metrics (flood frequency, shoreline retreat, insurance signals, etc.). All triggers assume monitoring systems are in place (see section f).
#
# Baseline metrics to monitor (for triggering)
# - Nuisance flooding days per year in key neighborhoods.
# - Shoreline retreat rate (meters per year) at strategic transects.
# - Insurance cost indices and coverage saturation (private- vs. public-insurance involvement).
# - Major-event overtopping or infrastructure performance during design-storm events.
#
# Decade 1 (Years 1–10): soft-first, evidence-building
# - Interventions
#   - Policy: adopt updated flood codes; adopt voluntary buyout/relocation framework; land-use planning updates to reduce new development in high-risk zones.
#   - NBIs: launch wetlands/restoration projects; urban green infrastructure pilot projects; living shorelines in selected bays/estuary edges; introduce rain garden networks and permeable pavements in new developments.
#   - Social: expand affordable-housing protections, elevate critical utilities, and increase community-based emergency response capacity.
#   - Finance: establish resilience fund; pilot affordable resilience insurance subsidies; begin early conversations about resilience-linked bonds.
# - Triggers to move to decade 2
#   - Cumulative nuisance-flood days in targeted districts exceed 40 days/year for two consecutive years (or a rising trend with a 3-year moving average).
#   - Shoreline retreat rates at critical transects reach >0.15–0.25 m/year for two consecutive measurement cycles.
#   - Private insurance market shows persistent rating/coverage tightening (e.g., >15% cost increase or >10% of properties seeking public insurance support).
# - Expected outcomes (approximate)
#   - Reduced immediate risk in many neighborhoods; improved public awareness and acceptance of risk-reduction measures; better data for decision-making.
#
# Decade 2 (Years 11–20): scale NBIs; begin targeted soft-to-hard transition
# - Interventions
#   - Policy: formalize zoning adjustments and hazard-mapping; begin targeted buyouts/relocation in the most exposed blocks; refine permit incentives tied to resilience retrofits.
#   - NBIs: scale up multi-purpose NBIs (coastal wetlands, mangroves if applicable, dune systems) and expanded urban green infrastructure.
#   - Social: expand housing retrofits; widen access to affordable risk-reduction programs; community-led adaptation planning workshops.
#   - Structural pilot programs: construct modular protection features at one or two pilot sites where risk is highest but where community support is strongest.
# - Triggers to move to decade 3
#   - Nuisance-flood days exceed 60 days/year in multiple neighborhoods for 2 consecutive years.
#   - Overtopping/surge-event damage exceedances at pilot sites during a major storm (or repeated near-misses) indicate current soft measures are insufficient in those zones.
#   - Insurance price signals continue to tighten for a sustained period (e.g., >20% year-over-year increase for two consecutive years).
# - Expected outcomes
#   - NBIs deliver measurable co-benefits (coastal protection, biodiversity, flood risk reduction, health improvements). Some neighborhoods begin to see declines in exposure.
#
# Decade 3 (Years 21–30): targeted hardening in the highest-risk zones
# - Interventions
#   - Structural investments begin in the highest-risk corridors where NBIs and policy measures do not fully avert risk; e.g., flood walls, sea barriers, pumping improvements, upgraded tide gates.
#   - Policy: formalized and funded buyout/relocation programs with adequate housing and job assistance in destination neighborhoods; risk-sharing mechanisms that reduce inequitable burdens.
#   - Social: targeted assistance for displaced households; job retraining and new economic opportunities for affected neighborhoods.
#   - NBIs: continued expansion and maintenance of living shorelines and green infrastructure; ensure climate-resilient urban design.
# - Triggers to move to decade 4
#   - In the high-risk zones, cumulative flood-related damages (including nuisance and major events) exceed threshold costs for NBIs vs. hard infrastructure (economic breakeven).
#   - Shoreline retreat rates in high-risk segments approach 0.3–0.5 m/year or higher for a sustained period.
# - Expected outcomes
#   - Hard protections reduce risk to critical infrastructure; households in most exposed areas have access to safer housing options; risk-reduction returns.
#
# Decade 4 (Years 31–40): consolidate defenses; intensify managed retreat where needed; optimize resilience
# - Interventions
#   - Structural defenses are completed in priority corridors; maintain NBIs as complementary protections; optimize drainage networks city-wide.
#   - Clarify long-term financing; establish a resilient-growth governance model; scale resilient land-use plans to reduce exposure from future growth.
#   - Social and equity: implement ongoing support for communities in transition; ensure equitable access to new housing and employment opportunities; maintain cultural and social networks during relocations.
# - Triggers to move to decade 5
#   - If high-SLR scenario remains plausible, and risk remains above acceptable thresholds in core urban zones, further hardening is prioritized; if buyouts have progressed well, monitor for social cohesion and community continuity.
# - Expected outcomes
#   - A robust, multi-layered defense system; fewer repeated losses; substantial risk-sharing and equitable adaptation.
#
# Decade 5 (Years 41–50): long-term adaptation governance; possible consolidation or withdrawal from high-risk zones
# - Interventions
#   - Maintain and upgrade robust protection measures; ensure NBIs are integrated into city planning as standard infrastructure; monitor for climate-change-driven shifts in hazard distribution.
#   - Social: finalize relocation/retreat programs where necessary; maintain strong social safety nets for displaced populations.
#   - Policy: formalize a long-term resilience fund; create governance that can adapt to new climate realities and population changes.
# - Triggers to reassess mid- to late-century options
#   - If SLR remains high (2.0 m by 2100) and risk distribution remains unfavorable, intensify managed retreat in extremely exposed zones while prioritizing equity and community support.
#   - If SLR is lower, maintain a less aggressive stance and re-evaluate risk targets to protect the urban core while preserving growth opportunities.
#
# (c) Budget allocation and trade-offs under the constraint (10% of city GDP per decade)
# Assumptions used here: city GDP ~ $75B/year; decade budget cap ~ $7.5B. Allocations reflect a balance among NBIs, policy/planning, social programs, and selective structural investments. Budgets shown in rough shares and dollars for clarity; per-decade allocation can be adjusted to the actual GDP trajectory and the SLR scenario.
#
# Overall per-decade allocation (illustrative, mid-range planning)
# - Nature-based and soft infrastructure (NBIs, green-blue corridors, wetlands, dune restoration, urban green infrastructure, water-sensitive urban design): 40–50% of decade budget
#   - dollars (example): $3.0–$3.75B
# - Policy, planning, governance, and social equity programs (land-use updates, building codes, zoning, buyout/relocation programs, affordable housing, insurance subsidies, emergency preparedness): 25–35%
#   - dollars: $1.9–$2.6B
# - Structural and hard infrastructure (critical drainage, pumping, floodwalls, surge barriers, tidal gates) (incremental, scalable, targeted to risk hotspots): 15–25%
#   - dollars: $1.1–$1.9B
# - Operations, maintenance, and contingency (O&M, monitoring, data systems, maintenance of NBIs, reserve fund): 5–10%
#   - dollars: $0.4–$0.75B
# - Contingency and innovation fund (pilot tests, adaptive management, learning-based refinements): 5–10%
#   - dollars: $0.4–$0.75B
#
# Note on differentiation by SLR scenario
# - Low SLR (0.6 m): emphasis remains on NBIs and social programs; structural investments are smaller and tied to demonstrable needs, with maintenance as a primary ongoing cost.
# - Mid SLR (1.2 m): balanced approach; NBIs remain central but additional targeted structural investments in high-risk zones are justified as risk indicators rise.
# - High SLR (2.0 m): early and more substantial NBIs (to avoid costly hard defenses where possible); targeted, prioritized structural investments in only the most critical corridors; intensified buyouts/relocation plans in the most exposed neighborhoods; ensure resilience financing is robust.
#
# ( d ) Expected outcomes under each sea-level scenario
# These are estimates designed to be policy-relevant, not precise predictions. They rely on the planned mix of NBIs, policy measures, social programs, and limited structural investments. They assume disciplined implementation and the presence of triggers that scale interventions as risk grows.
#
# - Low SLR (0.6 m by 2100)
#   - Estimated cumulative lives saved over 50 years: ~80–150 lives
#   - Economic losses avoided (undiscounted): ~$25–40B
#   - Inequality measures: exposure inequality reduced modestly; the relative vulnerability of low-income households declines as NBIs and social programs protect the most exposed; Gini-like exposure index improves by ~0.01–0.04 points
# - Mid SLR (1.2 m by 2100)
#   - Estimated cumulative lives saved: ~60–130 lives
#   - Economic losses avoided: ~$20–50B
#   - Inequality measures: noticeable improvement in equity as protections and subsidies focus on vulnerable neighborhoods; exposure index improvement ~0.02–0.07
# - High SLR (2.0 m by 2100)
#   - Estimated cumulative lives saved: ~40–100 lives
#   - Economic losses avoided: ~$12–60B (heavily dependent on buyouts and relocation effectiveness)
#   - Inequality measures: greater focus on equitable protection; potential for displacement if not carefully managed; exposure index improvement ~0.01–0.05, but with risk of temporary setback if displacement harms social cohesion
#
# Important note on uncertainty
# - These are policy-off results conditioned on timely and well-executed implementation. In all scenarios, the plan aims to maximize resilience and equity, but actual outcomes depend on governance, financing, public acceptance, climate trajectory, and maintenance.
#
# (e) The three most important uncertainties and a prioritized plan to reduce them
# Top uncertainties
# 1) Local SLR trajectory and subsidence (urban-specific amplification of global SLR)
# 2) Effectiveness and durability of nature-based solutions (NBIs) and maintenance costs
# 3) Equity impacts and social acceptance (who benefits, who bears costs, and how displacement is handled)
#
# Plan to reduce uncertainties (prioritized)
# - Uncertainty 1: Local SLR and subsidence
#   - Action: invest in high-resolution monitoring and data collection; deploy LiDAR/topographic surveys; establish a time-series shoreline/land subsidence map; integrate with tidal gauge data and local hydrogeology studies; institute a regularly updated local sea-level rise model with subsidence corrections; run scenario analyses with evolving data.
# - Uncertainty 2: NBIs performance and costs
#   - Action: implement a robust pilot program with controlled experiments (e.g., test different living shoreline designs, maintenance costs, and ecosystem benefits); standardize performance metrics (erosion control, flood attenuation, habitat creation); create a post-implementation monitoring framework; establish a financing plan that includes maintenance contingencies and adaptive management budgets.
# - Uncertainty 3: Equity, social acceptance, and displacement effects
#   - Action: intensify participatory planning with affected communities; measure social indicators (displacement risk, access to services, job security, and housing affordability) and adjust policies accordingly; publish transparent equity metrics; ensure legally protective measures and redress options are in place before large relocations or buyouts; implement independent oversight and community feedback loops.
#
# (f) Three monitoring metrics and thresholds for changing strategy
# - Metric 1: Nuisance flooding frequency in key neighborhoods
#   - Threshold to escalate from soft to structural measures: sustained increase to >60 nuisance-flood days/year in multiple neighborhoods for two consecutive years, or a rising 3-year moving average trend (significant, persistent increase).
# - Metric 2: Shoreline retreat rate at critical transects
#   - Threshold to escalate: retreat rate exceeding 0.3–0.5 m/year for two consecutive measurement cycles; if proprietary sensors indicate acceleration due to subsidence or maintenance shortfalls, adjust plan immediately.
# - Metric 3: Insurance and financial signals
#   - Threshold to escalate: private insurers withdraw or raise premiums by >20% year-over-year for two consecutive years; or the city experiences a material increase in uninsured exposure or failure of coverage on essential properties; triggers a shift from NBIs to targeted structural investments and enhanced social protection.
#
# (g) Three ethically contentious decisions and rationale
# 1) Managed retreat in high-risk neighborhoods
# - Why this choice: reduces long-term risk to residents and city budgets; but threatens home ownership, neighborhood fabric, and cultural ties.
# - How to communicate and mitigate harms: ensure voluntary participation, strong housing options, fair compensation, job relocation assistance, and robust social programs; provide meaningful community engagement, transparent criteria, and ensure no forced displacements without consent.
# 2) Differential investment by neighborhood (prioritize protection for lower-income areas or critical service hubs)
# - Why this choice: aligns protection with vulnerability and ensures essential services; risk of perceived inequity or “favoring some neighborhoods over others.”
# - How to communicate and mitigate harms: implement a transparent, needs-based scoring system; publish district-level risk and resilience profiles; ensure that all communities see long-term benefits and have clear paths to participate in decision-making.
# 3) Buyouts and long-term relocation programs
# - Why this choice: may be the most sustainable long-term option for some neighborhoods facing chronic risk; raises concerns about community disruption and affordable housing in destination neighborhoods.
# - How to communicate and mitigate harms: ensure fair compensation, preserve social networks and access to livelihoods, provide relocation assistance, and ensure replacement housing options meet affordability and proximity to jobs; maintain ongoing community engagement and post-relocation supports.
#
# (Ways to communicate and mitigate harms)
# - Public participation: early and ongoing community engagement; accessible information; multilingual communications.
# - Equity safeguards: ensure that vulnerable groups receive targeted assistance; track and publish equity indicators.
# - Transparency and accountability: independent oversight; public dashboards showing cost, risk reduction, and social outcomes.
# - Compensation and support: financial support, job training, and housing options that minimize disruption to livelihoods and social networks.
#
# ( h ) Strategy critique: three plausible failure modes, earliest warning signs, and contingency actions
# 1) Failure mode: underfunding or delayed financing prevents roll-out of critical NBIs and social protections
# - Early warning signs: rising maintenance backlogs; inability to deliver planned retrofits on schedule; public sentiment shifts toward questioning the value of resilience investments.
# - Contingency actions: activate reserve funds; pursue emergency bridging finance (climate resilience bonds); reprioritize projects toward highest-risk zones; seek state/federal grants or public-private partnerships to accelerate delivery; fast-track pay-as-you-go measures for high-ROI NBIs.
# 2) Failure mode: ineffective community engagement leading to low adoption of expensive measures or displacement backlash
# - Early warning signs: neighborhood opposition, rumors about eminent domain, or protests against relocation plans; lagging uptake of retrofit subsidies or insurance programs.
# - Contingency actions: pause contentious elements, broaden stakeholder engagement, co-design solutions with communities, adopt more voluntary and culturally sensitive approaches, and implement stronger economic and social protections for affected households.
# 3) Failure mode: decision inertia and political turnover undermining long-term resilience governance
# - Early warning signs: frequent policy reversals, inconsistent funding, and uncertain management structures; erosion of cross-agency collaboration.
# - Contingency actions: establish independent resilience authority or permanent cross-departmental governance body; enshrine core resilience objectives in city charter or enduring legislative framework; lock in funding streams via long-term bonds and dedicated reserves; create public accountability mechanisms (annual resilience report, citizen oversight).
#
# Final notes and practicalities
# - The proposed strategy is designed to be resilient to a wide range of SLR outcomes (low, mid, high) and takes into account the city’s budget constraint. It emphasizes equity and social protection for low-income residents and communities most at risk.
# - It is important to maintain a robust monitoring program (physical sensors, wetland health, shoreline mapping, socio-economic indicators) and to update the plan periodically in light of new data, changing climate conditions, and community feedback.
# - Success hinges on transparent governance, credible financing, and continuous community engagement. If managed well, the plan can substantially reduce risk, protect lives and livelihoods, and improve city resilience and quality of life under all SLR scenarios.
#
# If you’d like, I can convert this into a formal 50-year program document with costed line items, explicit annual budgets per department, and a risk register.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 model_name = "claude-sonnet-4-5"
#       5 claude = Anthropic()
# ----> 6 response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
#       7 answer = response.content[0].text
#       9 display(Markdown(answer))
#
# File ~/Documents/AgenticLearning/agents/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/Documents/AgenticLearning/agents/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File ~/Documents/AgenticLearning/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1324, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1310 def post(
#    1311     self,
#    1312     path: str,
#    (...)   1319     stream_cls: type[_StreamT] | None = None,
#    1320 ) -> ResponseT | _StreamT:
#    1321     opts = FinalRequestOptions.construct(
#    1322         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1323     )
# -> 1324     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/AgenticLearning/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1033, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1030 options = self._prepare_options(options)
#    1032 remaining_retries = max_retries - retries_taken
# -> 1033 request = self._build_request(options, retries_taken=retries_taken)
#    1034 self._prepare_request(request)
#    1036 kwargs: HttpxSendArgs = {}
#
# File ~/Documents/AgenticLearning/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:506, in BaseClient._build_request(self, options, retries_taken)
#     503     else:
#     504         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 506 headers = self._build_headers(options, retries_taken=retries_taken)
#     507 params = _merge_mappings(self.default_query, options.params)
#     508 content_type = headers.get("Content-Type")
#
# File ~/Documents/AgenticLearning/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:447, in BaseClient._build_headers(self, options, retries_taken)
#     437 custom_headers = options.headers or {}
#     438 headers_dict = _merge_mappings(
#     439     {
#     440         "x-stainless-timeout": str(options.timeout.read)
#    (...)    445     custom_headers,
#     446 )
# --> 447 self._validate_headers(headers_dict, custom_headers)
#     449 # headers are case-insensitive while dictionaries are not.
#     450 headers = httpx.Headers(headers_dict)
#
# File ~/Documents/AgenticLearning/agents/.venv/lib/python3.12/site-packages/anthropic/_client.py:196, in Anthropic._validate_headers(self, headers, custom_headers)
#     193 if isinstance(custom_headers.get("Authorization"), Omit):
#     194     return
# --> 196 raise TypeError(
#     197     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     198 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.2 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 5.3 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 5.3 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 8.7 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  15 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  20 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  28 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  43 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  47 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  56 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  66 MB/2.0 GB   63 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  68 MB/2.0 GB   63 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  79 MB/2.0 GB   63 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  87 MB/2.0 GB   63 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  92 MB/2.0 GB   63 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  99 MB/2.0 GB   63 MB/s     30spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB   63 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 113 MB/2.0 GB   63 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 123 MB/2.0 GB   63 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 132 MB/2.0 GB   63 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 136 MB/2.0 GB   63 MB/s     29spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 143 MB/2.0 GB   69 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 155 MB/2.0 GB   69 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 158 MB/2.0 GB   69 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 170 MB/2.0 GB   69 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 179 MB/2.0 GB   69 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 184 MB/2.0 GB   69 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 193 MB/2.0 GB   69 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 202 MB/2.0 GB   69 MB/s     26spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 206 MB/2.0 GB   69 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 215 MB/2.0 GB   69 MB/s     25spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 226 MB/2.0 GB   72 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 229 MB/2.0 GB   72 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 237 MB/2.0 GB   72 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 248 MB/2.0 GB   72 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 254 MB/2.0 GB   72 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 264 MB/2.0 GB   72 MB/s     24spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 272 MB/2.0 GB   72 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 276 MB/2.0 GB   72 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 278 MB/2.0 GB   72 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 296 MB/2.0 GB   72 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 300 MB/2.0 GB   74 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 307 MB/2.0 GB   74 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 320 MB/2.0 GB   74 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 323 MB/2.0 GB   74 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 333 MB/2.0 GB   74 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 341 MB/2.0 GB   74 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 346 MB/2.0 GB   74 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 352 MB/2.0 GB   74 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 362 MB/2.0 GB   74 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 366 MB/2.0 GB   74 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 376 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 387 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 392 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 402 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 413 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 417 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 428 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 434 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 437 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 447 MB/2.0 GB   74 MB/s     21spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 460 MB/2.0 GB   76 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 464 MB/2.0 GB   76 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 473 MB/2.0 GB   76 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 483 MB/2.0 GB   76 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 488 MB/2.0 GB   76 MB/s     20spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 496 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 501 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 508 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 517 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 527 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 532 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 541 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 549 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 554 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  28% ▕████              ▏ 560 MB/2.0 GB   76 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 566 MB/2.0 GB   76 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 573 MB/2.0 GB   76 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 579 MB/2.0 GB   76 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 589 MB/2.0 GB   76 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 593 MB/2.0 GB   76 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 603 MB/2.0 GB   76 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 613 MB/2.0 GB   75 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 618 MB/2.0 GB   75 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 628 MB/2.0 GB   75 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 638 MB/2.0 GB   75 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 643 MB/2.0 GB   75 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 654 MB/2.0 GB   75 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 664 MB/2.0 GB   75 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 669 MB/2.0 GB   75 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 679 MB/2.0 GB   75 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 690 MB/2.0 GB   75 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 695 MB/2.0 GB   77 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 705 MB/2.0 GB   77 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 715 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 719 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 727 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 738 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 743 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 752 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 756 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 758 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 762 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 772 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  39% ▕██████            ▏ 777 MB/2.0 GB   77 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  39% ▕███████           ▏ 786 MB/2.0 GB   77 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  39% ▕███████           ▏ 797 MB/2.0 GB   77 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 802 MB/2.0 GB   77 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 812 MB/2.0 GB   77 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 822 MB/2.0 GB   77 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 828 MB/2.0 GB   77 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 836 MB/2.0 GB   77 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 848 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 852 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 861 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 865 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 871 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 883 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 890 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 896 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 906 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 913 MB/2.0 GB   78 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 919 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 929 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 940 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 943 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 955 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 965 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 969 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 978 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 987 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 991 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 998 MB/2.0 GB   78 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  50% ▕████████          ▏ 1.0 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  50% ▕█████████         ▏ 1.0 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.0 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.1 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB   78 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  61% ▕███████████       ▏ 1.2 GB/2.0 GB   78 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.2 GB/2.0 GB   78 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB   78 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  72% ▕████████████      ▏ 1.5 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  72% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   79 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.5 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  78% ▕█████████████     ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  78% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB   80 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   81 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   81 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB   81 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   81 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB   81 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   81 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB   81 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   81 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   81 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB   81 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   82 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB   82 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   82 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  89% ▕███████████████   ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   82 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   82 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB   82 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   82 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   82 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB   82 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   81 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB   81 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   81 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB   81 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  96% ▕█████████████████ ▏ 1.9 GB/2.0 GB   81 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  96% ▕█████████████████ ▏ 1.9 GB/2.0 GB   81 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  96% ▕█████████████████ ▏ 1.9 GB/2.0 GB   81 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   81 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   81 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB   81 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB   80 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# ...
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Adaptation Strategy (50-year plan)**
#
# **Prioritization Framework**
#
# 1. Structural interventions prioritize sea wall construction, dune restoration, and flood gate installations.
# 2. Policy interventions focus on zoning regulations, building codes, and infrastructure upgrades.
# 3. Social programs target vulnerable populations with financial assistance, relocation support, and education.
# 4. Nature-based solutions emphasize green infrastructure development.
#
# **Decade-by-Decade Timeline**
#
# 1. 2025-2030:
# 	* Trigger: Increasing frequency of nuisance flooding (<5 events/decimal).
# 	* Interventions: Implement urban drainage system upgrades (Policy).
# 2. 2030-2035:
# 	* Trigger: Shoreline retreat rate increases to 0.1 m/decade.
# 	* Interventions: Start dune restoration and beach nourishment programs (Nature-based, Policy).
# 3. 2035-2040:
# 	* Trigger: Insurance cost increases by >2%.
# 	* Interventions: Construct moderate sea walls (<1m) in high-risk areas (Structural, Policy).
# 4. 2040-2045:
# 	* Trigger: Sea-level rise projections converge to >1.5 m.
# 	* Interventions: Initiate full-scale sea wall construction and floodgate installations (Structural).
# 	* Differential investment by neighborhood considered for extreme risk zones.
#
# **Budget Allocation**
#
# * Total budget constraint: 10% of current city GDP / decade.
# * Allocating 60% to Structural interventions, 20% to Policy strategies, 15% to Social programs, and 5% to Nature-based solutions.
#
# **Expected Outcomes (2100 Scenarios)**
#
# 1. Low Sea-Level Rise (0.6 m): Estimated:
# 	+ Lives saved: 100
# 	+ Economic losses avoided: $1 billion
# 	+ Reduced inequality measure: 2%
# 2. Mid-Sea-Level Rise (1.2 m): Estimated:
# 	+ Lives saved: 500
# 	+ Economic losses avoided: $10 billion
# 	+ Reduced inequality measure: 6%
# 3. High Sea-Level Rise (2.0 m): Estimated:
# 	+ Lives saved: 1,000
# 	+ Economic losses avoided: $50 billion
# 	+ Reduced inequality measure: 12%
#
# **Uncertainties**
#
# 1. Scientific uncertainty:
#  * Mitigation plan: Develop advanced coastal monitoring systems and perform detailed risk assessments for urban areas.
# 2. Economic uncertainty:
#  + Mitigation plan: Monitor economic performance closely, adapting business strategies to minimize losses when faced with increased flooding.
# 3. Social uncertainty:
#  + Mitigation plan: Prioritize public engagement, fostering inclusivity in decision-making processes for residents.
#
# **Monitoring Metrics and Thresholds**
#
# 1. Frequency of Nuisance Flooding: >5 events/decade (Trigger 2025-2030).
# 2. Shoreline Retreat Rate: >0.15 m/decade (Trigger 2030-2040).
# 3. Insurance Cost Increases: >3% annually.
#
# **Ethically Controversial Decisions**
#
# 1. **Managed Retreat**: A section designated for planned sinking and relocation.
#    - Justifies implementation over public education campaigns, aiming to preserve critical infrastructure and urban spaces.
#    - Effective mitigation involves transparent dialogue and support networks for residents impacted by the decision.
#
# 2. Differential investment by Neighborhoood for extreme risk zones:
#    Prioritize targeted investments addressing heightened flood risks while offering equitable benefits to the affected communities.
#    To mitigate potential disparity: Implement a participatory, evidence-based development plan ensuring representation from both the benefited community members and their needs within broader policy decisions.
#
# 3. Selective displacement strategy:
# To accommodate residents at risk of being displaced without sacrificing urban areas.
# - Facilitate inclusive communication with residents regarding available options, including relocation support services and financial compensation or alternatives like rehousements to neighboring properties.
# - Manage concerns by transparently planning community projects to minimize loss of social unity and preserve the sense of home.
#
# **Failure Modes and Contingency Actions**
#
# 1. **Increased insurance costs over projected levels**: Adapt budgetary allocation as per revised projections, ensuring continuous spending meets constraints while optimizing outcomes through targeted risk mitigation strategies.
#
# 2. Impact from underestimating projected sea-level rise: Implement early, multi-decade scale-up of urban planning measures to effectively protect infrastructure in anticipation of higher-than-expected rates.
#
# 3. Failure in monitoring effectiveness or oversight leading to inadequate timely interventions:
# Adapt communication channels and strategic planning methodologies regularly to keep community members updated on their safety expectations regarding rising sea levels through the city's adaptation policy guidance.
#    - Use cutting-edge data analytics tools and involve more localized residents during decision-making phases for better outcomes.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'llama3.2']
# ['Below is a complete 50-year adaptation strategy for a coastal city of 1,000,000 residents, with median income about 20% below the national average, currently "moderate" flood defenses, and a constraint that adaptation spending cannot exceed 10% of current city GDP per decade. Sea-level rise (SLR) by 2100 is uncertain and modeled with three scenarios: low 0.6 m, mid 1.2 m, high 2.0 m.\n\nKey assumptions (to keep the strategy concrete)\n- City GDP (current): about $75B/year. Adaptation spending ceiling: up to $7.5B per decade (10% of annual GDP, applied per-decade planning horizon).\n- Population and vulnerability: 1,000,000 residents; a substantial fraction of low-to-moderate income households live in neighborhoods exposed to nuisance flooding, drainage constraints, and shoreline retreat.\n- Existing defenses: “moderate” performance; some gates, embankments, and drainage networks that work under current loads but are stressed with higher water levels and more frequent Overtopping events.\n- Baseline hazard without adaptation: increasing nuisance flooding, groundwater rise, and occasional major storm surge events; direct annual economic losses and potential fatalities are non-negligible and rise with SLR.\n- Discount rate and time preference: standard municipal planning conventions (moderate discount rate, long-run geographies).\n\n(a) Priorities and sequencing of interventions (structural, policy, social programs, nature-based solutions) with justification\nOverarching sequencing principle: start with low-cost, high-visibility, high-leverage soft interventions that reduce risk quickly, build legitimacy, and protect vulnerable populations; progressively layer on nature-based and structural measures as data accumulate; reserve the most expensive, hard infrastructure for when triggers indicate necessity. This minimizes risk of stranded assets and respects equity constraints.\n\n1) Soft wins in the near term (Years 1–5)\n- Policy and planning\n  - Update land-use plans to minimize new development in high-risk zones; strengthen building codes for flood resilience (e.g., elevated foundations, floodproofing, watertight envelopes).\n  - Adopt performance-based flood insurance subsidies tied to resilient retrofits; expand a city resilience fund and create a simple, transparent buyout/relocation framework for the most exposed properties.\n  - Enable “managed retreat” options as a voluntary, supportive pathway (no forced relocation) with fair compensation and moving assistance.\n- Social protection and equity\n  - Expand affordable housing near lower-risk areas; provide targeted grants for at-risk households to elevate utilities and critical systems (electric, water, sewer), and to retrofit homes.\n  - Establish a city-wide early warning system, community flood-alert drills, and neighborhood-level emergency response teams; prioritize low-income communities.\n- Nature-based solutions (NBIs) with fast-install potential\n  - Restore and expand blue-green corridors: wetlands restoration, living shorelines, mangroves (where applicable), and dune systems in amenity-rich and key flood-prone corridors.\n  - Implement green infrastructure in urban cores (bioswales, porous pavements, tree canopies, rooftop gardens) to reduce surface runoff and urban heat island effects that intensify flood impacts.\n- Insurance and finance\n  - Create or expand an affordable-resilience insurance program, with subsidized premiums for properties that adopt prescribed retrofit standards.\n- Monitoring and learning\n  - Install a dedicated resilience data platform to track performance, costs, and social outcomes; publish annual progress reports to maintain accountability.\n\n2) Early modification of risk surface and targeted hardening (Years 6–15)\n- Policy and planning\n  - Implement spatially explicit risk zoning with credible buyout corridors for the most exposed blocks; begin strategic relocation in the highest-risk neighborhoods if supported by community engagem ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Below is a complete 50-year adaptation strategy for a coastal city of 1,000,000 residents, with median income about 20% below the national average, currently "moderate" flood defenses, and a constraint that adaptation spending cannot exceed 10% of current city GDP per decade. Sea-level rise (SLR) by 2100 is uncertain and modeled with three scenarios: low 0.6 m, mid 1.2 m, high 2.0 m.
#
# Key assumptions (to keep the strategy concrete)
# - City GDP (current): about $75B/year. Adaptation spending ceiling: up to $7.5B per decade (10% of annual GDP, applied per-decade planning horizon).
# - Population and vulnerability: 1,000,000 residents; a substantial fraction of low-to-moderate income households live in neighborhoods exposed to nuisance flooding, drainage constraints, and shoreline retreat.
# - Existing defenses: “moderate” performance; some gates, embankments, and drainage networks that work under current loads but are stressed with higher water levels and more frequent Overtopping events.
# - Baseline hazard without adaptation: increasing nuisance flooding, groundwater rise, and occasional major storm surge events; direct annual economic losses and potential fatalities are non-negligible and rise with SLR.
# - Discount rate and time preference: standard municipal planning conventions (moderate discount rate, long-run geographies).
#
# (a) Priorities and sequencing of interventions (structural, policy, social programs, nature-based solutions) with justification
# Overarching sequencing principle: start with low-cost, high-visibility, high-leverage soft interventions that reduce risk quickly, build legitimacy, and protect vulnerable populations; progressively layer on nature-based and structural measures as data accumulate; reserve the most expensive, hard infrastructure for when triggers indicate necessity. This minimizes risk of stranded assets and respects equity constraints.
#
# 1) Soft wins in the near term (Years 1–5)
# - Policy and planning
#   - Update land-use plans to minimize new development in high-risk zones; strengthen building codes for flood resilience (e.g., elevated foundations, floodproofing, watertight envelopes).
#   - Adopt performance-based flood insurance subsidies tied to resilient retrofits; expand a city resilience fund and create a simple, transparent buyout/relocation framework for the most exposed properties.
#   - Enable “managed retreat” options as a voluntary, supportive pathway (no forced relocation) with fair compensation and moving assistance.
# - Social protection and equity
#   - Expand affordable housing near lower-risk areas; provide targeted grants for at-risk households to elevate utilities and critical systems (electric, water, sewer), and to retrofit homes.
#   - Establish a city-wide early warning system, community flood-alert drills, and neighborhood-level emergency response teams; prioritize low-income communities.
# - Nature-based solutions (NBIs) with fast-install potential
#   - Restore and expand blue-green corridors: wetlands restoration, living shorelines, mangroves (where applicable), and dune systems in amenity-rich and key flood-prone corridors.
#   - Implement green infrastructure in urban cores (bioswales, porous pavements, tree canopies, rooftop gardens) to reduce surface runoff and urban heat island effects that intensify flood impacts.
# - Insurance and finance
#   - Create or expand an affordable-resilience insurance program, with subsidized premiums for properties that adopt prescribed retrofit standards.
# - Monitoring and learning
#   - Install a dedicated resilience data platform to track performance, costs, and social outcomes; publish annual progress reports to maintain accountability.
#
# 2) Early modification of risk surface and targeted hardening (Years 6–15)
# - Policy and planning
#   - Implement spatially explicit risk zoning with credible buyout corridors for the most exposed blocks; begin strategic relocation in the highest-risk neighborhoods if supported by community engagement.
#   - Update local permit review thresholds to require flood-resilience retrofits for existing buildings in hazard zones.
# - NBIs and green-gray hybrids
#   - Scale up nature-based defense: multi-purpose marsh restoration, living shorelines on critical waterfront interfaces, and coastal dune system restoration in front of key neighborhoods and public assets.
# - Social programs
#   - Expand affordable home elevation subsidies and microgrants for risk-reducing upgrades; expand training programs to create local jobs in resilience projects.
# - Structural elements (pilot scale)
#   - Install modular, scalable stormwater pumps and gravity drainage improvements in selected flood-prone districts; pilot sea barriers only in areas with demonstrated exposure and community buy-in.
#
# 3) Strategic escalation to structural defense (Years 16–30)
# - Structural defense
#   - Based on triggers (see section b), begin large-scale flood defenses in the most exposed corridors: flood walls, surge barriers, strengthened levees, and upstream drainage enhancements to reduce backflow and overtopping.
# - NBIs and urban design
#   - Continue to expand NBIs, focusing on living shoreline continuity, restored wetlands, and integrated green roofs across the city’s neighborhoods to reduce energy, flooding, and heat exposure simultaneously.
# - Social programs and policy
#   - Scale buyouts/relocation programs with clear, community-driven criteria; ensure that vulnerable populations are not disproportionately displaced; ensure housing alternatives that preserve access to jobs and services.
# - Evaluation and maintenance planning
#   - Create formal maintenance plans and reserve funds for NBIs, urban green infrastructure, and structural defenses; integrate long-term asset management planning.
#
# 4) Full-scale resilience and adaptive governance (Years 31–50)
# - Structural and multi-layer defenses
#   - Implement high-capacity, multi-layer defenses in the most exposed corridors where risk remains high after NBIs; this includes tide gates, larger-scale flood barriers, and comprehensive drainage networks designed for current and projected loads.
# - Social protection and equity programs
#   - Institutionalize ongoing risk-sharing programs, targeted subsidies, and community-led adaptation planning; ensure that resilience benefits and costs are equitably distributed.
# - Nature-based stabilization and restoration
#   - Achieve a broad network of NBIs that provide flood protection, biodiversity benefits, coastal protection, and recreational value; maintain and expand green corridors city-wide.
# - Governance and finance
#   - Establish a long-term resilience bond program, with explicit use of proceeds for NBIs, housing resilience, and hazard mitigation; ensure transparency and citizen oversight.
#
# (b) Decade-by-decade timeline with triggers tied to observable metrics
# The triggers are designed to shift the plan gradually from soft to hard interventions as risk exposure grows or remains elevated. Triggers rely on observable metrics (flood frequency, shoreline retreat, insurance signals, etc.). All triggers assume monitoring systems are in place (see section f).
#
# Baseline metrics to monitor (for triggering)
# - Nuisance flooding days per year in key neighborhoods.
# - Shoreline retreat rate (meters per year) at strategic transects.
# - Insurance cost indices and coverage saturation (private- vs. public-insurance involvement).
# - Major-event overtopping or infrastructure performance during design-storm events.
#
# Decade 1 (Years 1–10): soft-first, evidence-building
# - Interventions
#   - Policy: adopt updated flood codes; adopt voluntary buyout/relocation framework; land-use planning updates to reduce new development in high-risk zones.
#   - NBIs: launch wetlands/restoration projects; urban green infrastructure pilot projects; living shorelines in selected bays/estuary edges; introduce rain garden networks and permeable pavements in new developments.
#   - Social: expand affordable-housing protections, elevate critical utilities, and increase community-based emergency response capacity.
#   - Finance: establish resilience fund; pilot affordable resilience insurance subsidies; begin early conversations about resilience-linked bonds.
# - Triggers to move to decade 2
#   - Cumulative nuisance-flood days in targeted districts exceed 40 days/year for two consecutive years (or a rising trend with a 3-year moving average).
#   - Shoreline retreat rates at critical transects reach >0.15–0.25 m/year for two consecutive measurement cycles.
#   - Private insurance market shows persistent rating/coverage tightening (e.g., >15% cost increase or >10% of properties seeking public insurance support).
# - Expected outcomes (approximate)
#   - Reduced immediate risk in many neighborhoods; improved public awareness and acceptance of risk-reduction measures; better data for decision-making.
#
# Decade 2 (Years 11–20): scale NBIs; begin targeted soft-to-hard transition
# - Interventions
#   - Policy: formalize zoning adjustments and hazard-mapping; begin targeted buyouts/relocation in the most exposed blocks; refine permit incentives tied to resilience retrofits.
#   - NBIs: scale up multi-purpose NBIs (coastal wetlands, mangroves if applicable, dune systems) and expanded urban green infrastructure.
#   - Social: expand housing retrofits; widen access to affordable risk-reduction programs; community-led adaptation planning workshops.
#   - Structural pilot programs: construct modular protection features at one or two pilot sites where risk is highest but where community support is strongest.
# - Triggers to move to decade 3
#   - Nuisance-flood days exceed 60 days/year in multiple neighborhoods for 2 consecutive years.
#   - Overtopping/surge-event damage exceedances at pilot sites during a major storm (or repeated near-misses) indicate current soft measures are insufficient in those zones.
#   - Insurance price signals continue to tighten for a sustained period (e.g., >20% year-over-year increase for two consecutive years).
# - Expected outcomes
#   - NBIs deliver measurable co-benefits (coastal protection, biodiversity, flood risk reduction, health improvements). Some neighborhoods begin to see declines in exposure.
#
# Decade 3 (Years 21–30): targeted hardening in the highest-risk zones
# - Interventions
#   - Structural investments begin in the highest-risk corridors where NBIs and policy measures do not fully avert risk; e.g., flood walls, sea barriers, pumping improvements, upgraded tide gates.
#   - Policy: formalized and funded buyout/relocation programs with adequate housing and job assistance in destination neighborhoods; risk-sharing mechanisms that reduce inequitable burdens.
#   - Social: targeted assistance for displaced households; job retraining and new economic opportunities for affected neighborhoods.
#   - NBIs: continued expansion and maintenance of living shorelines and green infrastructure; ensure climate-resilient urban design.
# - Triggers to move to decade 4
#   - In the high-risk zones, cumulative flood-related damages (including nuisance and major events) exceed threshold costs for NBIs vs. hard infrastructure (economic breakeven).
#   - Shoreline retreat rates in high-risk segments approach 0.3–0.5 m/year or higher for a sustained period.
# - Expected outcomes
#   - Hard protections reduce risk to critical infrastructure; households in most exposed areas have access to safer housing options; risk-reduction returns.
#
# Decade 4 (Years 31–40): consolidate defenses; intensify managed retreat where needed; optimize resilience
# - Interventions
#   - Structural defenses are completed in priority corridors; maintain NBIs as complementary protections; optimize drainage networks city-wide.
#   - Clarify long-term financing; establish a resilient-growth governance model; scale resilient land-use plans to reduce exposure from future growth.
#   - Social and equity: implement ongoing support for communities in transition; ensure equitable access to new housing and employment opportunities; maintain cultural and social networks during relocations.
# - Triggers to move to decade 5
#   - If high-SLR scenario remains plausible, and risk remains above acceptable thresholds in core urban zones, further hardening is prioritized; if buyouts have progressed well, monitor for social cohesion and community continuity.
# - Expected outcomes
#   - A robust, multi-layered defense system; fewer repeated losses; substantial risk-sharing and equitable adaptation.
#
# Decade 5 (Years 41–50): long-term adaptation governance; possible consolidation or withdrawal from high-risk zones
# - Interventions
#   - Maintain and upgrade robust protection measures; ensure NBIs are integrated into city planning as standard infrastructure; monitor for climate-change-driven shifts in hazard distribution.
#   - Social: finalize relocation/retreat programs where necessary; maintain strong social safety nets for displaced populations.
#   - Policy: formalize a long-term resilience fund; create governance that can adapt to new climate realities and population changes.
# - Triggers to reassess mid- to late-century options
#   - If SLR remains high (2.0 m by 2100) and risk distribution remains unfavorable, intensify managed retreat in extremely exposed zones while prioritizing equity and community support.
#   - If SLR is lower, maintain a less aggressive stance and re-evaluate risk targets to protect the urban core while preserving growth opportunities.
#
# (c) Budget allocation and trade-offs under the constraint (10% of city GDP per decade)
# Assumptions used here: city GDP ~ $75B/year; decade budget cap ~ $7.5B. Allocations reflect a balance among NBIs, policy/planning, social programs, and selective structural investments. Budgets shown in rough shares and dollars for clarity; per-decade allocation can be adjusted to the actual GDP trajectory and the SLR scenario.
#
# Overall per-decade allocation (illustrative, mid-range planning)
# - Nature-based and soft infrastructure (NBIs, green-blue corridors, wetlands, dune restoration, urban green infrastructure, water-sensitive urban design): 40–50% of decade budget
#   - dollars (example): $3.0–$3.75B
# - Policy, planning, governance, and social equity programs (land-use updates, building codes, zoning, buyout/relocation programs, affordable housing, insurance subsidies, emergency preparedness): 25–35%
#   - dollars: $1.9–$2.6B
# - Structural and hard infrastructure (critical drainage, pumping, floodwalls, surge barriers, tidal gates) (incremental, scalable, targeted to risk hotspots): 15–25%
#   - dollars: $1.1–$1.9B
# - Operations, maintenance, and contingency (O&M, monitoring, data systems, maintenance of NBIs, reserve fund): 5–10%
#   - dollars: $0.4–$0.75B
# - Contingency and innovation fund (pilot tests, adaptive management, learning-based refinements): 5–10%
#   - dollars: $0.4–$0.75B
#
# Note on differentiation by SLR scenario
# - Low SLR (0.6 m): emphasis remains on NBIs and social programs; structural investments are smaller and tied to demonstrable needs, with maintenance as a primary ongoing cost.
# - Mid SLR (1.2 m): balanced approach; NBIs remain central but additional targeted structural investments in high-risk zones are justified as risk indicators rise.
# - High SLR (2.0 m): early and more substantial NBIs (to avoid costly hard defenses where possible); targeted, prioritized structural investments in only the most critical corridors; intensified buyouts/relocation plans in the most exposed neighborhoods; ensure resilience financing is robust.
#
# ( d ) Expected outcomes under each sea-level scenario
# These are estimates designed to be policy-relevant, not precise predictions. They rely on the planned mix of NBIs, policy measures, social programs, and limited structural investments. They assume disciplined implementation and the presence of triggers that scale interventions as risk grows.
#
# - Low SLR (0.6 m by 2100)
#   - Estimated cumulative lives saved over 50 years: ~80–150 lives
#   - Economic losses avoided (undiscounted): ~$25–40B
#   - Inequality measures: exposure inequality reduced modestly; the relative vulnerability of low-income households declines as NBIs and social programs protect the most exposed; Gini-like exposure index improves by ~0.01–0.04 points
# - Mid SLR (1.2 m by 2100)
#   - Estimated cumulative lives saved: ~60–130 lives
#   - Economic losses avoided: ~$20–50B
#   - Inequality measures: noticeable improvement in equity as protections and subsidies focus on vulnerable neighborhoods; exposure index improvement ~0.02–0.07
# - High SLR (2.0 m by 2100)
#   - Estimated cumulative lives saved: ~40–100 lives
#   - Economic losses avoided: ~$12–60B (heavily dependent on buyouts and relocation effectiveness)
#   - Inequality measures: greater focus on equitable protection; potential for displacement if not carefully managed; exposure index improvement ~0.01–0.05, but with risk of temporary setback if displacement harms social cohesion
#
# Important note on uncertainty
# - These are policy-off results conditioned on timely and well-executed implementation. In all scenarios, the plan aims to maximize resilience and equity, but actual outcomes depend on governance, financing, public acceptance, climate trajectory, and maintenance.
#
# (e) The three most important uncertainties and a prioritized plan to reduce them
# Top uncertainties
# 1) Local SLR trajectory and subsidence (urban-specific amplification of global SLR)
# 2) Effectiveness and durability of nature-based solutions (NBIs) and maintenance costs
# 3) Equity impacts and social acceptance (who benefits, who bears costs, and how displacement is handled)
#
# Plan to reduce uncertainties (prioritized)
# - Uncertainty 1: Local SLR and subsidence
#   - Action: invest in high-resolution monitoring and data collection; deploy LiDAR/topographic surveys; establish a time-series shoreline/land subsidence map; integrate with tidal gauge data and local hydrogeology studies; institute a regularly updated local sea-level rise model with subsidence corrections; run scenario analyses with evolving data.
# - Uncertainty 2: NBIs performance and costs
#   - Action: implement a robust pilot program with controlled experiments (e.g., test different living shoreline designs, maintenance costs, and ecosystem benefits); standardize performance metrics (erosion control, flood attenuation, habitat creation); create a post-implementation monitoring framework; establish a financing plan that includes maintenance contingencies and adaptive management budgets.
# - Uncertainty 3: Equity, social acceptance, and displacement effects
#   - Action: intensify participatory planning with affected communities; measure social indicators (displacement risk, access to services, job security, and housing affordability) and adjust policies accordingly; publish transparent equity metrics; ensure legally protective measures and redress options are in place before large relocations or buyouts; implement independent oversight and community feedback loops.
#
# (f) Three monitoring metrics and thresholds for changing strategy
# - Metric 1: Nuisance flooding frequency in key neighborhoods
#   - Threshold to escalate from soft to structural measures: sustained increase to >60 nuisance-flood days/year in multiple neighborhoods for two consecutive years, or a rising 3-year moving average trend (significant, persistent increase).
# - Metric 2: Shoreline retreat rate at critical transects
#   - Threshold to escalate: retreat rate exceeding 0.3–0.5 m/year for two consecutive measurement cycles; if proprietary sensors indicate acceleration due to subsidence or maintenance shortfalls, adjust plan immediately.
# - Metric 3: Insurance and financial signals
#   - Threshold to escalate: private insurers withdraw or raise premiums by >20% year-over-year for two consecutive years; or the city experiences a material increase in uninsured exposure or failure of coverage on essential properties; triggers a shift from NBIs to targeted structural investments and enhanced social protection.
#
# (g) Three ethically contentious decisions and rationale
# 1) Managed retreat in high-risk neighborhoods
# - Why this choice: reduces long-term risk to residents and city budgets; but threatens home ownership, neighborhood fabric, and cultural ties.
# - How to communicate and mitigate harms: ensure voluntary participation, strong housing options, fair compensation, job relocation assistance, and robust social programs; provide meaningful community engagement, transparent criteria, and ensure no forced displacements without consent.
# 2) Differential investment by neighborhood (prioritize protection for lower-income areas or critical service hubs)
# - Why this choice: aligns protection with vulnerability and ensures essential services; risk of perceived inequity or “favoring some neighborhoods over others.”
# - How to communicate and mitigate harms: implement a transparent, needs-based scoring system; publish district-level risk and resilience profiles; ensure that all communities see long-term benefits and have clear paths to participate in decision-making.
# 3) Buyouts and long-term relocation programs
# - Why this choice: may be the most sustainable long-term option for some neighborhoods facing chronic risk; raises concerns about community disruption and affordable housing in destination neighborhoods.
# - How to communicate and mitigate harms: ensure fair compensation, preserve social networks and access to livelihoods, provide relocation assistance, and ensure replacement housing options meet affordability and proximity to jobs; maintain ongoing community engagement and post-relocation supports.
#
# (Ways to communicate and mitigate harms)
# - Public participation: early and ongoing community engagement; accessible information; multilingual communications.
# - Equity safeguards: ensure that vulnerable groups receive targeted assistance; track and publish equity indicators.
# - Transparency and accountability: independent oversight; public dashboards showing cost, risk reduction, and social outcomes.
# - Compensation and support: financial support, job training, and housing options that minimize disruption to livelihoods and social networks.
#
# ( h ) Strategy critique: three plausible failure modes, earliest warning signs, and contingency actions
# 1) Failure mode: underfunding or delayed financing prevents roll-out of critical NBIs and social protections
# - Early warning signs: rising maintenance backlogs; inability to deliver planned retrofits on schedule; public sentiment shifts toward questioning the value of resilience investments.
# - Contingency actions: activate reserve funds; pursue emergency bridging finance (climate resilience bonds); reprioritize projects toward highest-risk zones; seek state/federal grants or public-private partnerships to accelerate delivery; fast-track pay-as-you-go measures for high-ROI NBIs.
# 2) Failure mode: ineffective community engagement leading to low adoption of expensive measures or displacement backlash
# - Early warning signs: neighborhood opposition, rumors about eminent domain, or protests against relocation plans; lagging uptake of retrofit subsidies or insurance programs.
# - Contingency actions: pause contentious elements, broaden stakeholder engagement, co-design solutions with communities, adopt more voluntary and culturally sensitive approaches, and implement stronger economic and social protections for affected households.
# 3) Failure mode: decision inertia and political turnover undermining long-term resilience governance
# - Early warning signs: frequent policy reversals, inconsistent funding, and uncertain management structures; erosion of cross-agency collaboration.
# - Contingency actions: establish independent resilience authority or permanent cross-departmental governance body; enshrine core resilience objectives in city charter or enduring legislative framework; lock in funding streams via long-term bonds and dedicated reserves; create public accountability mechanisms (annual resilience report, citizen oversight).
#
# Final notes and practicalities
# - The proposed strategy is designed to be resilient to a wide range of SLR outcomes (low, mid, high) and takes into account the city’s budget constraint. It emphasizes equity and social protection for low-income residents and communities most at risk.
# - It is important to maintain a robust monitoring program (physical sensors, wetland health, shoreline mapping, socio-economic indicators) and to update the plan periodically in light of new data, changing climate conditions, and community feedback.
# - Success hinges on transparent governance, credible financing, and continuous community engagement. If managed well, the plan can substantially reduce risk, protect lives and livelihoods, and improve city resilience and quality of life under all SLR scenarios.
#
# If you’d like, I can convert this into a formal 50-year program document with costed line items, explicit annual budgets per department, and a risk register.
# Competitor: llama3.2
#
# **Adaptation Strategy (50-year plan)**
#
# **Prioritization Framework**
#
# 1. Structural interventions prioritize sea wall construction, dune restoration, and flood gate installations.
# 2. Policy interventions focus on zoning regulations, building codes, and infrastructure upgrades.
# 3. Social programs target vulnerable populations with financial assistance, relocation support, and education.
# 4. Nature-based solutions emphasize green infrastructure development.
#
# **Decade-by-Decade Timeline**
#
# 1. 2025-2030:
# 	* Trigger: Increasing frequency of nuisance flooding (<5 events/decimal).
# 	* Interventions: Implement urban drainage system upgrades (Policy).
# 2. 2030-2035:
# 	* Trigger: Shoreline retreat rate increases to 0.1 m/decade.
# 	* Interventions: Start dune restoration and beach nourishment programs (Nature-based, Policy).
# 3. 2035-2040:
# 	* Trigger: Insurance cost increases by >2%.
# 	* Interventions: Construct moderate sea walls (<1m) in high-risk areas (Structural, Policy).
# 4. 2040-2045:
# 	* Trigger: Sea-level rise projections converge to >1.5 m.
# 	* Interventions: Initiate full-scale sea wall construction and floodgate installations (Structural).
# 	* Differential investment by neighborhood considered for extreme risk zones.
#
# **Budget Allocation**
#
# * Total budget constraint: 10% of current city GDP / decade.
# * Allocating 60% to Structural interventions, 20% to Policy strategies, 15% to Social programs, and 5% to Nature-based solutions.
#
# **Expected Outcomes (2100 Scenarios)**
#
# 1. Low Sea-Level Rise (0.6 m): Estimated:
# 	+ Lives saved: 100
# 	+ Economic losses avoided: $1 billion
# 	+ Reduced inequality measure: 2%
# 2. Mid-Sea-Level Rise (1.2 m): Estimated:
# 	+ Lives saved: 500
# 	+ Economic losses avoided: $10 billion
# 	+ Reduced inequality measure: 6%
# 3. High Sea-Level Rise (2.0 m): Estimated:
# 	+ Lives saved: 1,000
# 	+ Economic losses avoided: $50 billion
# 	+ Reduced inequality measure: 12%
#
# **Uncertainties**
#
# 1. Scientific uncertainty:
#  * Mitigation plan: Develop advanced coastal monitoring systems and perform detailed risk assessments for urban areas.
# 2. Economic uncertainty:
#  + Mitigation plan: Monitor economic performance closely, adapting business strategies to minimize losses when faced with increased flooding.
# 3. Social uncertainty:
#  + Mitigation plan: Prioritize public engagement, fostering inclusivity in decision-making processes for residents.
#
# **Monitoring Metrics and Thresholds**
#
# 1. Frequency of Nuisance Flooding: >5 events/decade (Trigger 2025-2030).
# 2. Shoreline Retreat Rate: >0.15 m/decade (Trigger 2030-2040).
# 3. Insurance Cost Increases: >3% annually.
#
# **Ethically Controversial Decisions**
#
# 1. **Managed Retreat**: A section designated for planned sinking and relocation.
#    - Justifies implementation over public education campaigns, aiming to preserve critical infrastructure and urban spaces.
#    - Effective mitigation involves transparent dialogue and support networks for residents impacted by the decision.
#
# 2. Differential investment by Neighborhoood for extreme risk zones:
#    Prioritize targeted investments addressing heightened flood risks while offering equitable benefits to the affected communities.
#    To mitigate potential disparity: Implement a participatory, evidence-based development plan ensuring representation from both the benefited community members and their needs within broader policy decisions.
#
# 3. Selective displacement strategy:
# To accommodate residents at risk of being displaced without sacrificing urban areas.
# - Facilitate inclusive communication with residents regarding available options, including relocation support services and financial compensation or alternatives like rehousements to neighboring properties.
# - Manage concerns by transparently planning community projects to minimize loss of social unity and preserve the sense of home.
#
# **Failure Modes and Contingency Actions**
#
# 1. **Increased insurance costs over projected levels**: Adapt budgetary allocation as per revised projections, ensuring continuous spending meets constraints while optimizing outcomes through targeted risk mitigation strategies.
#
# 2. Impact from underestimating projected sea-level rise: Implement early, multi-decade scale-up of urban planning measures to effectively protect infrastructure in anticipation of higher-than-expected rates.
#
# 3. Failure in monitoring effectiveness or oversight leading to inadequate timely interventions:
# Adapt communication channels and strategic planning methodologies regularly to keep community members updated on their safety expectations regarding rising sea levels through the city's adaptation policy guidance.
#    - Use cutting-edge data analytics tools and involve more localized residents during decision-making phases for better outcomes.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Below is a complete 50-year adaptation strategy for a coastal city of 1,000,000 residents, with median income about 20% below the national average, currently "moderate" flood defenses, and a constraint that adaptation spending cannot exceed 10% of current city GDP per decade. Sea-level rise (SLR) by 2100 is uncertain and modeled with three scenarios: low 0.6 m, mid 1.2 m, high 2.0 m.
#
# Key assumptions (to keep the strategy concrete)
# - City GDP (current): about $75B/year. Adaptation spending ceiling: up to $7.5B per decade (10% of annual GDP, applied per-decade planning horizon).
# - Population and vulnerability: 1,000,000 residents; a substantial fraction of low-to-moderate income households live in neighborhoods exposed to nuisance flooding, drainage constraints, and shoreline retreat.
# - Existing defenses: “moderate” performance; some gates, embankments, and drainage networks that work under current loads but are stressed with higher water levels and more frequent Overtopping events.
# - Baseline hazard without adaptation: increasing nuisance flooding, groundwater rise, and occasional major storm surge events; direct annual economic losses and potential fatalities are non-negligible and rise with SLR.
# - Discount rate and time preference: standard municipal planning conventions (moderate discount rate, long-run geographies).
#
# (a) Priorities and sequencing of interventions (structural, policy, social programs, nature-based solutions) with justification
# Overarching sequencing principle: start with low-cost, high-visibility, high-leverage soft interventions that reduce risk quickly, build legitimacy, and protect vulnerable populations; progressively layer on nature-based and structural measures as data accumulate; reserve the most expensive, hard infrastructure for when triggers indicate necessity. This minimizes risk of stranded assets and respects equity constraints.
#
# 1) Soft wins in the near term (Years 1–5)
# - Policy and planning
#   - Update land-use plans to minimize new development in high-risk zones; strengthen building codes for flood resilience (e.g., elevated foundations, floodproofing, watertight envelopes).
#   - Adopt performance-based flood insurance subsidies tied to resilient retrofits; expand a city resilience fund and create a simple, transparent buyout/relocation framework for the most exposed properties.
#   - Enable “managed retreat” options as a voluntary, supportive pathway (no forced relocation) with fair compensation and moving assistance.
# - Social protection and equity
#   - Expand affordable housing near lower-risk areas; provide targeted grants for at-risk households to elevate utilities and critical systems (electric, water, sewer), and to retrofit homes.
#   - Establish a city-wide early warning system, community flood-alert drills, and neighborhood-level emergency response teams; prioritize low-income communities.
# - Nature-based solutions (NBIs) with fast-install potential
#   - Restore and expand blue-green corridors: wetlands restoration, living shorelines, mangroves (where applicable), and dune systems in amenity-rich and key flood-prone corridors.
#   - Implement green infrastructure in urban cores (bioswales, porous pavements, tree canopies, rooftop gardens) to reduce surface runoff and urban heat island effects that intensify flood impacts.
# - Insurance and finance
#   - Create or expand an affordable-resilience insurance program, with subsidized premiums for properties that adopt prescribed retrofit standards.
# - Monitoring and learning
#   - Install a dedicated resilience data platform to track performance, costs, and social outcomes; publish annual progress reports to maintain accountability.
#
# 2) Early modification of risk surface and targeted hardening (Years 6–15)
# - Policy and planning
#   - Implement spatially explicit risk zoning with credible buyout corridors for the most exposed blocks; begin strategic relocation in the highest-risk neighborhoods if supported by community engagement.
#   - Update local permit review thresholds to require flood-resilience retrofits for existing buildings in hazard zones.
# - NBIs and green-gray hybrids
#   - Scale up nature-based defense: multi-purpose marsh restoration, living shorelines on critical waterfront interfaces, and coastal dune system restoration in front of key neighborhoods and public assets.
# - Social programs
#   - Expand affordable home elevation subsidies and microgrants for risk-reducing upgrades; expand training programs to create local jobs in resilience projects.
# - Structural elements (pilot scale)
#   - Install modular, scalable stormwater pumps and gravity drainage improvements in selected flood-prone districts; pilot sea barriers only in areas with demonstrated exposure and community buy-in.
#
# 3) Strategic escalation to structural defense (Years 16–30)
# - Structural defense
#   - Based on triggers (see section b), begin large-scale flood defenses in the most exposed corridors: flood walls, surge barriers, strengthened levees, and upstream drainage enhancements to reduce backflow and overtopping.
# - NBIs and urban design
#   - Continue to expand NBIs, focusing on living shoreline continuity, restored wetlands, and integrated green roofs across the city’s neighborhoods to reduce energy, flooding, and heat exposure simultaneously.
# - Social programs and policy
#   - Scale buyouts/relocation programs with clear, community-driven criteria; ensure that vulnerable populations are not disproportionately displaced; ensure housing alternatives that preserve access to jobs and services.
# - Evaluation and maintenance planning
#   - Create formal maintenance plans and reserve funds for NBIs, urban green infrastructure, and structural defenses; integrate long-term asset management planning.
#
# 4) Full-scale resilience and adaptive governance (Years 31–50)
# - Structural and multi-layer defenses
#   - Implement high-capacity, multi-layer defenses in the most exposed corridors where risk remains high after NBIs; this includes tide gates, larger-scale flood barriers, and comprehensive drainage networks designed for current and projected loads.
# - Social protection and equity programs
#   - Institutionalize ongoing risk-sharing programs, targeted subsidies, and community-led adaptation planning; ensure that resilience benefits and costs are equitably distributed.
# - Nature-based stabilization and restoration
#   - Achieve a broad network of NBIs that provide flood protection, biodiversity benefits, coastal protection, and recreational value; maintain and expand green corridors city-wide.
# - Governance and finance
#   - Establish a long-term resilience bond program, with explicit use of proceeds for NBIs, housing resilience, and hazard mitigation; ensure transparency and citizen oversight.
#
# (b) Decade-by-decade timeline with triggers tied to observable metrics
# The triggers are designed to shift the plan gradually from soft to hard interventions as risk exposure grows or remains elevated. Triggers rely on observable metrics (flood frequency, shoreline retreat, insurance signals, etc.). All triggers assume monitoring systems are in place (see section f).
#
# Baseline metrics to monitor (for triggering)
# - Nuisance flooding days per year in key neighborhoods.
# - Shoreline retreat rate (meters per year) at strategic transects.
# - Insurance cost indices and coverage saturation (private- vs. public-insurance involvement).
# - Major-event overtopping or infrastructure performance during design-storm events.
#
# Decade 1 (Years 1–10): soft-first, evidence-building
# - Interventions
#   - Policy: adopt updated flood codes; adopt voluntary buyout/relocation framework; land-use planning updates to reduce new development in high-risk zones.
#   - NBIs: launch wetlands/restoration projects; urban green infrastructure pilot projects; living shorelines in selected bays/estuary edges; introduce rain garden networks and permeable pavements in new developments.
#   - Social: expand affordable-housing protections, elevate critical utilities, and increase community-based emergency response capacity.
#   - Finance: establish resilience fund; pilot affordable resilience insurance subsidies; begin early conversations about resilience-linked bonds.
# - Triggers to move to decade 2
#   - Cumulative nuisance-flood days in targeted districts exceed 40 days/year for two consecutive years (or a rising trend with a 3-year moving average).
#   - Shoreline retreat rates at critical transects reach >0.15–0.25 m/year for two consecutive measurement cycles.
#   - Private insurance market shows persistent rating/coverage tightening (e.g., >15% cost increase or >10% of properties seeking public insurance support).
# - Expected outcomes (approximate)
#   - Reduced immediate risk in many neighborhoods; improved public awareness and acceptance of risk-reduction measures; better data for decision-making.
#
# Decade 2 (Years 11–20): scale NBIs; begin targeted soft-to-hard transition
# - Interventions
#   - Policy: formalize zoning adjustments and hazard-mapping; begin targeted buyouts/relocation in the most exposed blocks; refine permit incentives tied to resilience retrofits.
#   - NBIs: scale up multi-purpose NBIs (coastal wetlands, mangroves if applicable, dune systems) and expanded urban green infrastructure.
#   - Social: expand housing retrofits; widen access to affordable risk-reduction programs; community-led adaptation planning workshops.
#   - Structural pilot programs: construct modular protection features at one or two pilot sites where risk is highest but where community support is strongest.
# - Triggers to move to decade 3
#   - Nuisance-flood days exceed 60 days/year in multiple neighborhoods for 2 consecutive years.
#   - Overtopping/surge-event damage exceedances at pilot sites during a major storm (or repeated near-misses) indicate current soft measures are insufficient in those zones.
#   - Insurance price signals continue to tighten for a sustained period (e.g., >20% year-over-year increase for two consecutive years).
# - Expected outcomes
#   - NBIs deliver measurable co-benefits (coastal protection, biodiversity, flood risk reduction, health improvements). Some neighborhoods begin to see declines in exposure.
#
# Decade 3 (Years 21–30): targeted hardening in the highest-risk zones
# - Interventions
#   - Structural investments begin in the highest-risk corridors where NBIs and policy measures do not fully avert risk; e.g., flood walls, sea barriers, pumping improvements, upgraded tide gates.
#   - Policy: formalized and funded buyout/relocation programs with adequate housing and job assistance in destination neighborhoods; risk-sharing mechanisms that reduce inequitable burdens.
#   - Social: targeted assistance for displaced households; job retraining and new economic opportunities for affected neighborhoods.
#   - NBIs: continued expansion and maintenance of living shorelines and green infrastructure; ensure climate-resilient urban design.
# - Triggers to move to decade 4
#   - In the high-risk zones, cumulative flood-related damages (including nuisance and major events) exceed threshold costs for NBIs vs. hard infrastructure (economic breakeven).
#   - Shoreline retreat rates in high-risk segments approach 0.3–0.5 m/year or higher for a sustained period.
# - Expected outcomes
#   - Hard protections reduce risk to critical infrastructure; households in most exposed areas have access to safer housing options; risk-reduction returns.
#
# Decade 4 (Years 31–40): consolidate defenses; intensify managed retreat where needed; optimize resilience
# - Interventions
#   - Structural defenses are completed in priority corridors; maintain NBIs as complementary protections; optimize drainage networks city-wide.
#   - Clarify long-term financing; establish a resilient-growth governance model; scale resilient land-use plans to reduce exposure from future growth.
#   - Social and equity: implement ongoing support for communities in transition; ensure equitable access to new housing and employment opportunities; maintain cultural and social networks during relocations.
# - Triggers to move to decade 5
#   - If high-SLR scenario remains plausible, and risk remains above acceptable thresholds in core urban zones, further hardening is prioritized; if buyouts have progressed well, monitor for social cohesion and community continuity.
# - Expected outcomes
#   - A robust, multi-layered defense system; fewer repeated losses; substantial risk-sharing and equitable adaptation.
#
# Decade 5 (Years 41–50): long-term adaptation governance; possible consolidation or withdrawal from high-risk zones
# - Interventions
#   - Maintain and upgrade robust protection measures; ensure NBIs are integrated into city planning as standard infrastructure; monitor for climate-change-driven shifts in hazard distribution.
#   - Social: finalize relocation/retreat programs where necessary; maintain strong social safety nets for displaced populations.
#   - Policy: formalize a long-term resilience fund; create governance that can adapt to new climate realities and population changes.
# - Triggers to reassess mid- to late-century options
#   - If SLR remains high (2.0 m by 2100) and risk distribution remains unfavorable, intensify managed retreat in extremely exposed zones while prioritizing equity and community support.
#   - If SLR is lower, maintain a less aggressive stance and re-evaluate risk targets to protect the urban core while preserving growth opportunities.
#
# (c) Budget allocation and trade-offs under the constraint (10% of city GDP per decade)
# Assumptions used here: city GDP ~ $75B/year; decade budget cap ~ $7.5B. Allocations reflect a balance among NBIs, policy/planning, social programs, and selective structural investments. Budgets shown in rough shares and dollars for clarity; per-decade allocation can be adjusted to the actual GDP trajectory and the SLR scenario.
#
# Overall per-decade allocation (illustrative, mid-range planning)
# - Nature-based and soft infrastructure (NBIs, green-blue corridors, wetlands, dune restoration, urban green infrastructure, water-sensitive urban design): 40–50% of decade budget
#   - dollars (example): $3.0–$3.75B
# - Policy, planning, governance, and social equity programs (land-use updates, building codes, zoning, buyout/relocation programs, affordable housing, insurance subsidies, emergency preparedness): 25–35%
#   - dollars: $1.9–$2.6B
# - Structural and hard infrastructure (critical drainage, pumping, floodwalls, surge barriers, tidal gates) (incremental, scalable, targeted to risk hotspots): 15–25%
#   - dollars: $1.1–$1.9B
# - Operations, maintenance, and contingency (O&M, monitoring, data systems, maintenance of NBIs, reserve fund): 5–10%
#   - dollars: $0.4–$0.75B
# - Contingency and innovation fund (pilot tests, adaptive management, learning-based refinements): 5–10%
#   - dollars: $0.4–$0.75B
#
# Note on differentiation by SLR scenario
# - Low SLR (0.6 m): emphasis remains on NBIs and social programs; structural investments are smaller and tied to demonstrable needs, with maintenance as a primary ongoing cost.
# - Mid SLR (1.2 m): balanced approach; NBIs remain central but additional targeted structural investments in high-risk zones are justified as risk indicators rise.
# - High SLR (2.0 m): early and more substantial NBIs (to avoid costly hard defenses where possible); targeted, prioritized structural investments in only the most critical corridors; intensified buyouts/relocation plans in the most exposed neighborhoods; ensure resilience financing is robust.
#
# ( d ) Expected outcomes under each sea-level scenario
# These are estimates designed to be policy-relevant, not precise predictions. They rely on the planned mix of NBIs, policy measures, social programs, and limited structural investments. They assume disciplined implementation and the presence of triggers that scale interventions as risk grows.
#
# - Low SLR (0.6 m by 2100)
#   - Estimated cumulative lives saved over 50 years: ~80–150 lives
#   - Economic losses avoided (undiscounted): ~$25–40B
#   - Inequality measures: exposure inequality reduced modestly; the relative vulnerability of low-income households declines as NBIs and social programs protect the most exposed; Gini-like exposure index improves by ~0.01–0.04 points
# - Mid SLR (1.2 m by 2100)
#   - Estimated cumulative lives saved: ~60–130 lives
#   - Economic losses avoided: ~$20–50B
#   - Inequality measures: noticeable improvement in equity as protections and subsidies focus on vulnerable neighborhoods; exposure index improvement ~0.02–0.07
# - High SLR (2.0 m by 2100)
#   - Estimated cumulative lives saved: ~40–100 lives
#   - Economic losses avoided: ~$12–60B (heavily dependent on buyouts and relocation effectiveness)
#   - Inequality measures: greater focus on equitable protection; potential for displacement if not carefully managed; exposure index improvement ~0.01–0.05, but with risk of temporary setback if displacement harms social cohesion
#
# Important note on uncertainty
# - These are policy-off results conditioned on timely and well-executed implementation. In all scenarios, the plan aims to maximize resilience and equity, but actual outcomes depend on governance, financing, public acceptance, climate trajectory, and maintenance.
#
# (e) The three most important uncertainties and a prioritized plan to reduce them
# Top uncertainties
# 1) Local SLR trajectory and subsidence (urban-specific amplification of global SLR)
# 2) Effectiveness and durability of nature-based solutions (NBIs) and maintenance costs
# 3) Equity impacts and social acceptance (who benefits, who bears costs, and how displacement is handled)
#
# Plan to reduce uncertainties (prioritized)
# - Uncertainty 1: Local SLR and subsidence
#   - Action: invest in high-resolution monitoring and data collection; deploy LiDAR/topographic surveys; establish a time-series shoreline/land subsidence map; integrate with tidal gauge data and local hydrogeology studies; institute a regularly updated local sea-level rise model with subsidence corrections; run scenario analyses with evolving data.
# - Uncertainty 2: NBIs performance and costs
#   - Action: implement a robust pilot program with controlled experiments (e.g., test different living shoreline designs, maintenance costs, and ecosystem benefits); standardize performance metrics (erosion control, flood attenuation, habitat creation); create a post-implementation monitoring framework; establish a financing plan that includes maintenance contingencies and adaptive management budgets.
# - Uncertainty 3: Equity, social acceptance, and displacement effects
#   - Action: intensify participatory planning with affected communities; measure social indicators (displacement risk, access to services, job security, and housing affordability) and adjust policies accordingly; publish transparent equity metrics; ensure legally protective measures and redress options are in place before large relocations or buyouts; implement independent oversight and community feedback loops.
#
# (f) Three monitoring metrics and thresholds for changing strategy
# - Metric 1: Nuisance flooding frequency in key neighborhoods
#   - Threshold to escalate from soft to structural measures: sustained increase to >60 nuisance-flood days/year in multiple neighborhoods for two consecutive years, or a rising 3-year moving average trend (significant, persistent increase).
# - Metric 2: Shoreline retreat rate at critical transects
#   - Threshold to escalate: retreat rate exceeding 0.3–0.5 m/year for two consecutive measurement cycles; if proprietary sensors indicate acceleration due to subsidence or maintenance shortfalls, adjust plan immediately.
# - Metric 3: Insurance and financial signals
#   - Threshold to escalate: private insurers withdraw or raise premiums by >20% year-over-year for two consecutive years; or the city experiences a material increase in uninsured exposure or failure of coverage on essential properties; triggers a shift from NBIs to targeted structural investments and enhanced social protection.
#
# (g) Three ethically contentious decisions and rationale
# 1) Managed retreat in high-risk neighborhoods
# - Why this choice: reduces long-term risk to residents and city budgets; but threatens home ownership, neighborhood fabric, and cultural ties.
# - How to communicate and mitigate harms: ensure voluntary participation, strong housing options, fair compensation, job relocation assistance, and robust social programs; provide meaningful community engagement, transparent criteria, and ensure no forced displacements without consent.
# 2) Differential investment by neighborhood (prioritize protection for lower-income areas or critical service hubs)
# - Why this choice: aligns protection with vulnerability and ensures essential services; risk of perceived inequity or “favoring some neighborhoods over others.”
# - How to communicate and mitigate harms: implement a transparent, needs-based scoring system; publish district-level risk and resilience profiles; ensure that all communities see long-term benefits and have clear paths to participate in decision-making.
# 3) Buyouts and long-term relocation programs
# - Why this choice: may be the most sustainable long-term option for some neighborhoods facing chronic risk; raises concerns about community disruption and affordable housing in destination neighborhoods.
# - How to communicate and mitigate harms: ensure fair compensation, preserve social networks and access to livelihoods, provide relocation assistance, and ensure replacement housing options meet affordability and proximity to jobs; maintain ongoing community engagement and post-relocation supports.
#
# (Ways to communicate and mitigate harms)
# - Public participation: early and ongoing community engagement; accessible information; multilingual communications.
# - Equity safeguards: ensure that vulnerable groups receive targeted assistance; track and publish equity indicators.
# - Transparency and accountability: independent oversight; public dashboards showing cost, risk reduction, and social outcomes.
# - Compensation and support: financial support, job training, and housing options that minimize disruption to livelihoods and social networks.
#
# ( h ) Strategy critique: three plausible failure modes, earliest warning signs, and contingency actions
# 1) Failure mode: underfunding or delayed financing prevents roll-out of critical NBIs and social protections
# - Early warning signs: rising maintenance backlogs; inability to deliver planned retrofits on schedule; public sentiment shifts toward questioning the value of resilience investments.
# - Contingency actions: activate reserve funds; pursue emergency bridging finance (climate resilience bonds); reprioritize projects toward highest-risk zones; seek state/federal grants or public-private partnerships to accelerate delivery; fast-track pay-as-you-go measures for high-ROI NBIs.
# 2) Failure mode: ineffective community engagement leading to low adoption of expensive measures or displacement backlash
# - Early warning signs: neighborhood opposition, rumors about eminent domain, or protests against relocation plans; lagging uptake of retrofit subsidies or insurance programs.
# - Contingency actions: pause contentious elements, broaden stakeholder engagement, co-design solutions with communities, adopt more voluntary and culturally sensitive approaches, and implement stronger economic and social protections for affected households.
# 3) Failure mode: decision inertia and political turnover undermining long-term resilience governance
# - Early warning signs: frequent policy reversals, inconsistent funding, and uncertain management structures; erosion of cross-agency collaboration.
# - Contingency actions: establish independent resilience authority or permanent cross-departmental governance body; enshrine core resilience objectives in city charter or enduring legislative framework; lock in funding streams via long-term bonds and dedicated reserves; create public accountability mechanisms (annual resilience report, citizen oversight).
#
# Final notes and practicalities
# - The proposed strategy is designed to be resilient to a wide range of SLR outcomes (low, mid, high) and takes into account the city’s budget constraint. It emphasizes equity and social protection for low-income residents and communities most at risk.
# - It is important to maintain a robust monitoring program (physical sensors, wetland health, shoreline mapping, socio-economic indicators) and to update the plan periodically in light of new data, changing climate conditions, and community feedback.
# - Success hinges on transparent governance, credible financing, and continuous community engagement. If managed well, the plan can substantially reduce risk, protect lives and livelihoods, and improve city resilience and quality of life under all SLR scenarios.
#
# If you’d like, I can convert this into a formal 50-year program document with costed line items, explicit annual budgets per department, and a risk register.
#
# # Response from competitor 2
#
# **Adaptation Strategy (50-year plan)**
#
# **Prioritization Framework**
#
# 1. Structural interventions prioritize sea wall construction, dune restoration, and flood gate installations.
# 2. Policy interventions focus on zoning regulations, building codes, and infrastructure upgrades.
# 3. Social programs target vulnerable populations with financial assistance, relocation support, and education.
# 4. Nature-based solutions emphasize green infrastructure development.
#
# **Decade-by-Decade Timeline**
#
# 1. 2025-2030:
# 	* Trigger: Increasing frequency of nuisance flooding (<5 events/decimal).
# 	* Interventions: Implement urban drainage system upgrades (Policy).
# 2. 2030-2035:
# 	* Trigger: Shoreline retreat rate increases to 0.1 m/decade.
# 	* Interventions: Start dune restoration and beach nourishment programs (Nature-based, Policy).
# 3. 2035-2040:
# 	* Trigger: Insurance cost increases by >2%.
# 	* Interventions: Construct moderate sea walls (<1m) in high-risk areas (Structural, Policy).
# 4. 2040-2045:
# 	* Trigger: Sea-level rise projections converge to >1.5 m.
# 	* Interventions: Initiate full-scale sea wall construction and floodgate installations (Structural).
# 	* Differential investment by neighborhood considered for extreme risk zones.
#
# **Budget Allocation**
#
# * Total budget constraint: 10% of current city GDP / decade.
# * Allocating 60% to Structural interventions, 20% to Policy strategies, 15% to Social programs, and 5% to Nature-based solutions.
#
# **Expected Outcomes (2100 Scenarios)**
#
# 1. Low Sea-Level Rise (0.6 m): Estimated:
# 	+ Lives saved: 100
# 	+ Economic losses avoided: $1 billion
# 	+ Reduced inequality measure: 2%
# 2. Mid-Sea-Level Rise (1.2 m): Estimated:
# 	+ Lives saved: 500
# 	+ Economic losses avoided: $10 billion
# 	+ Reduced inequality measure: 6%
# 3. High Sea-Level Rise (2.0 m): Estimated:
# 	+ Lives saved: 1,000
# 	+ Economic losses avoided: $50 billion
# 	+ Reduced inequality measure: 12%
#
# **Uncertainties**
#
# 1. Scientific uncertainty:
#  * Mitigation plan: Develop advanced coastal monitoring systems and perform detailed risk assessments for urban areas.
# 2. Economic uncertainty:
#  + Mitigation plan: Monitor economic performance closely, adapting business strategies to minimize losses when faced with increased flooding.
# 3. Social uncertainty:
#  + Mitigation plan: Prioritize public engagement, fostering inclusivity in decision-making processes for residents.
#
# **Monitoring Metrics and Thresholds**
#
# 1. Frequency of Nuisance Flooding: >5 events/decade (Trigger 2025-2030).
# 2. Shoreline Retreat Rate: >0.15 m/decade (Trigger 2030-2040).
# 3. Insurance Cost Increases: >3% annually.
#
# **Ethically Controversial Decisions**
#
# 1. **Managed Retreat**: A section designated for planned sinking and relocation.
#    - Justifies implementation over public education campaigns, aiming to preserve critical infrastructure and urban spaces.
#    - Effective mitigation involves transparent dialogue and support networks for residents impacted by the decision.
#
# 2. Differential investment by Neighborhoood for extreme risk zones:
#    Prioritize targeted investments addressing heightened flood risks while offering equitable benefits to the affected communities.
#    To mitigate potential disparity: Implement a participatory, evidence-based development plan ensuring representation from both the benefited community members and their needs within broader policy decisions.
#
# 3. Selective displacement strategy:
# To accommodate residents at risk of being displaced without sacrificing urban areas.
# - Facilitate inclusive communication with residents regarding available options, including relocation support services and financial compensation or alternatives like rehousements to neighboring properties.
# - Manage concerns by transparently planning community projects to minimize loss of social unity and preserve the sense of home.
#
# **Failure Modes and Contingency Actions**
#
# 1. **Increased insurance costs over projected levels**: Adapt budgetary allocation as per revised projections, ensuring continuous spending meets constraints while optimizing outcomes through targeted risk mitigation strategies.
#
# 2. Impact from underestimating projected sea-level rise: Implement early, multi-decade scale-up of urban planning measures to effectively protect infrastructure in anticipation of higher-than-expected rates.
#
# 3. Failure in monitoring effectiveness or oversight leading to inadequate timely interventions:
# Adapt communication channels and strategic planning methodologies regularly to keep community members updated on their safety expectations regarding rising sea levels through the city's adaptation policy guidance.
#    - Use cutting-edge data analytics tools and involve more localized residents during decision-making phases for better outcomes.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 2 competitors.
# Each model has been given this question:
#
# You are acting as a multidisciplinary advisory panel (climatologist, urban planner, economist, civil engineer, public health expert, and ethicist) for a coastal city of 1,000,000 residents with median income 20% below the national average, existing flood defenses rated as "moderate," and a municipal budget constraint such that adaptation spending cannot exceed 10% of current city GDP per decade; sea-level rise projections for 2100 are uncertain but modeled as three scenarios (low 0.6 m, mid 1.2 m, high 2.0 m). Produce a complete 50-year adaptation strategy that: (a) prioritizes interventions (structural, policy, social programs, and nature-based solutions) with justification for sequencing; (b) provides a decade-by-decade timeline with specific triggers tied to observable metrics (e.g., frequency of nuisance flooding, shoreline retreat rate, insurance cost increases) that move the plan from soft to hard interventions; (c) allocates a plausible portion of the constrained budget across interventions and sectors, explaining trade-offs; (d) projects expected outcomes (estimated lives saved, economic losses avoided, and changes in inequality measures) under each sea-level scenario; (e) identifies the three most important scientific, economic, or social uncertainties, and gives a prioritized, realistic plan to reduce those uncertainties; (f) supplies three concrete monitoring metrics and thresholds for changing strategy; and (g) lists three ethically contentious decisions you would make (e.g., managed retreat, differential investment by neighborhood), explains why you chose them over alternatives, and outlines how you would communicate and mitigate the harms. Finally, critique your own strategy by naming three plausible failure modes, the earliest warning signs for each, and specific contingency actions to correct course.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Below is a complete 50-year adaptation strategy for a coastal city of 1,000,000 residents, with median income about 20% below the national average, currently "moderate" flood defenses, and a constraint that adaptation spending cannot exceed 10% of current city GDP per decade. Sea-level rise (SLR) by 2100 is uncertain and modeled with three scenarios: low 0.6 m, mid 1.2 m, high 2.0 m.
#
# Key assumptions (to keep the strategy concrete)
# - City GDP (current): about $75B/year. Adaptation spending ceiling: up to $7.5B per decade (10% of annual GDP, applied per-decade planning horizon).
# - Population and vulnerability: 1,000,000 residents; a substantial fraction of low-to-moderate income households live in neighborhoods exposed to nuisance flooding, drainage constraints, and shoreline retreat.
# - Existing defenses: “moderate” performance; some gates, embankments, and drainage networks that work under current loads but are stressed with higher water levels and more frequent Overtopping events.
# - Baseline hazard without adaptation: increasing nuisance flooding, groundwater rise, and occasional major storm surge events; direct annual economic losses and potential fatalities are non-negligible and rise with SLR.
# - Discount rate and time preference: standard municipal planning conventions (moderate discount rate, long-run geographies).
#
# (a) Priorities and sequencing of interventions (structural, policy, social programs, nature-based solutions) with justification
# Overarching sequencing principle: start with low-cost, high-visibility, high-leverage soft interventions that reduce risk quickly, build legitimacy, and protect vulnerable populations; progressively layer on nature-based and structural measures as data accumulate; reserve the most expensive, hard infrastructure for when triggers indicate necessity. This minimizes risk of stranded assets and respects equity constraints.
#
# 1) Soft wins in the near term (Years 1–5)
# - Policy and planning
#   - Update land-use plans to minimize new development in high-risk zones; strengthen building codes for flood resilience (e.g., elevated foundations, floodproofing, watertight envelopes).
#   - Adopt performance-based flood insurance subsidies tied to resilient retrofits; expand a city resilience fund and create a simple, transparent buyout/relocation framework for the most exposed properties.
#   - Enable “managed retreat” options as a voluntary, supportive pathway (no forced relocation) with fair compensation and moving assistance.
# - Social protection and equity
#   - Expand affordable housing near lower-risk areas; provide targeted grants for at-risk households to elevate utilities and critical systems (electric, water, sewer), and to retrofit homes.
#   - Establish a city-wide early warning system, community flood-alert drills, and neighborhood-level emergency response teams; prioritize low-income communities.
# - Nature-based solutions (NBIs) with fast-install potential
#   - Restore and expand blue-green corridors: wetlands restoration, living shorelines, mangroves (where applicable), and dune systems in amenity-rich and key flood-prone corridors.
#   - Implement green infrastructure in urban cores (bioswales, porous pavements, tree canopies, rooftop gardens) to reduce surface runoff and urban heat island effects that intensify flood impacts.
# - Insurance and finance
#   - Create or expand an affordable-resilience insurance program, with subsidized premiums for properties that adopt prescribed retrofit standards.
# - Monitoring and learning
#   - Install a dedicated resilience data platform to track performance, costs, and social outcomes; publish annual progress reports to maintain accountability.
#
# 2) Early modification of risk surface and targeted hardening (Years 6–15)
# - Policy and planning
#   - Implement spatially explicit risk zoning with credible buyout corridors for the most exposed blocks; begin strategic relocation in the highest-risk neighborhoods if supported by community engagement.
#   - Update local permit review thresholds to require flood-resilience retrofits for existing buildings in hazard zones.
# - NBIs and green-gray hybrids
#   - Scale up nature-based defense: multi-purpose marsh restoration, living shorelines on critical waterfront interfaces, and coastal dune system restoration in front of key neighborhoods and public assets.
# - Social programs
#   - Expand affordable home elevation subsidies and microgrants for risk-reducing upgrades; expand training programs to create local jobs in resilience projects.
# - Structural elements (pilot scale)
#   - Install modular, scalable stormwater pumps and gravity drainage improvements in selected flood-prone districts; pilot sea barriers only in areas with demonstrated exposure and community buy-in.
#
# 3) Strategic escalation to structural defense (Years 16–30)
# - Structural defense
#   - Based on triggers (see section b), begin large-scale flood defenses in the most exposed corridors: flood walls, surge barriers, strengthened levees, and upstream drainage enhancements to reduce backflow and overtopping.
# - NBIs and urban design
#   - Continue to expand NBIs, focusing on living shoreline continuity, restored wetlands, and integrated green roofs across the city’s neighborhoods to reduce energy, flooding, and heat exposure simultaneously.
# - Social programs and policy
#   - Scale buyouts/relocation programs with clear, community-driven criteria; ensure that vulnerable populations are not disproportionately displaced; ensure housing alternatives that preserve access to jobs and services.
# - Evaluation and maintenance planning
#   - Create formal maintenance plans and reserve funds for NBIs, urban green infrastructure, and structural defenses; integrate long-term asset management planning.
#
# 4) Full-scale resilience and adaptive governance (Years 31–50)
# - Structural and multi-layer defenses
#   - Implement high-capacity, multi-layer defenses in the most exposed corridors where risk remains high after NBIs; this includes tide gates, larger-scale flood barriers, and comprehensive drainage networks designed for current and projected loads.
# - Social protection and equity programs
#   - Institutionalize ongoing risk-sharing programs, targeted subsidies, and community-led adaptation planning; ensure that resilience benefits and costs are equitably distributed.
# - Nature-based stabilization and restoration
#   - Achieve a broad network of NBIs that provide flood protection, biodiversity benefits, coastal protection, and recreational value; maintain and expand green corridors city-wide.
# - Governance and finance
#   - Establish a long-term resilience bond program, with explicit use of proceeds for NBIs, housing resilience, and hazard mitigation; ensure transparency and citizen oversight.
#
# (b) Decade-by-decade timeline with triggers tied to observable metrics
# The triggers are designed to shift the plan gradually from soft to hard interventions as risk exposure grows or remains elevated. Triggers rely on observable metrics (flood frequency, shoreline retreat, insurance signals, etc.). All triggers assume monitoring systems are in place (see section f).
#
# Baseline metrics to monitor (for triggering)
# - Nuisance flooding days per year in key neighborhoods.
# - Shoreline retreat rate (meters per year) at strategic transects.
# - Insurance cost indices and coverage saturation (private- vs. public-insurance involvement).
# - Major-event overtopping or infrastructure performance during design-storm events.
#
# Decade 1 (Years 1–10): soft-first, evidence-building
# - Interventions
#   - Policy: adopt updated flood codes; adopt voluntary buyout/relocation framework; land-use planning updates to reduce new development in high-risk zones.
#   - NBIs: launch wetlands/restoration projects; urban green infrastructure pilot projects; living shorelines in selected bays/estuary edges; introduce rain garden networks and permeable pavements in new developments.
#   - Social: expand affordable-housing protections, elevate critical utilities, and increase community-based emergency response capacity.
#   - Finance: establish resilience fund; pilot affordable resilience insurance subsidies; begin early conversations about resilience-linked bonds.
# - Triggers to move to decade 2
#   - Cumulative nuisance-flood days in targeted districts exceed 40 days/year for two consecutive years (or a rising trend with a 3-year moving average).
#   - Shoreline retreat rates at critical transects reach >0.15–0.25 m/year for two consecutive measurement cycles.
#   - Private insurance market shows persistent rating/coverage tightening (e.g., >15% cost increase or >10% of properties seeking public insurance support).
# - Expected outcomes (approximate)
#   - Reduced immediate risk in many neighborhoods; improved public awareness and acceptance of risk-reduction measures; better data for decision-making.
#
# Decade 2 (Years 11–20): scale NBIs; begin targeted soft-to-hard transition
# - Interventions
#   - Policy: formalize zoning adjustments and hazard-mapping; begin targeted buyouts/relocation in the most exposed blocks; refine permit incentives tied to resilience retrofits.
#   - NBIs: scale up multi-purpose NBIs (coastal wetlands, mangroves if applicable, dune systems) and expanded urban green infrastructure.
#   - Social: expand housing retrofits; widen access to affordable risk-reduction programs; community-led adaptation planning workshops.
#   - Structural pilot programs: construct modular protection features at one or two pilot sites where risk is highest but where community support is strongest.
# - Triggers to move to decade 3
#   - Nuisance-flood days exceed 60 days/year in multiple neighborhoods for 2 consecutive years.
#   - Overtopping/surge-event damage exceedances at pilot sites during a major storm (or repeated near-misses) indicate current soft measures are insufficient in those zones.
#   - Insurance price signals continue to tighten for a sustained period (e.g., >20% year-over-year increase for two consecutive years).
# - Expected outcomes
#   - NBIs deliver measurable co-benefits (coastal protection, biodiversity, flood risk reduction, health improvements). Some neighborhoods begin to see declines in exposure.
#
# Decade 3 (Years 21–30): targeted hardening in the highest-risk zones
# - Interventions
#   - Structural investments begin in the highest-risk corridors where NBIs and policy measures do not fully avert risk; e.g., flood walls, sea barriers, pumping improvements, upgraded tide gates.
#   - Policy: formalized and funded buyout/relocation programs with adequate housing and job assistance in destination neighborhoods; risk-sharing mechanisms that reduce inequitable burdens.
#   - Social: targeted assistance for displaced households; job retraining and new economic opportunities for affected neighborhoods.
#   - NBIs: continued expansion and maintenance of living shorelines and green infrastructure; ensure climate-resilient urban design.
# - Triggers to move to decade 4
#   - In the high-risk zones, cumulative flood-related damages (including nuisance and major events) exceed threshold costs for NBIs vs. hard infrastructure (economic breakeven).
#   - Shoreline retreat rates in high-risk segments approach 0.3–0.5 m/year or higher for a sustained period.
# - Expected outcomes
#   - Hard protections reduce risk to critical infrastructure; households in most exposed areas have access to safer housing options; risk-reduction returns.
#
# Decade 4 (Years 31–40): consolidate defenses; intensify managed retreat where needed; optimize resilience
# - Interventions
#   - Structural defenses are completed in priority corridors; maintain NBIs as complementary protections; optimize drainage networks city-wide.
#   - Clarify long-term financing; establish a resilient-growth governance model; scale resilient land-use plans to reduce exposure from future growth.
#   - Social and equity: implement ongoing support for communities in transition; ensure equitable access to new housing and employment opportunities; maintain cultural and social networks during relocations.
# - Triggers to move to decade 5
#   - If high-SLR scenario remains plausible, and risk remains above acceptable thresholds in core urban zones, further hardening is prioritized; if buyouts have progressed well, monitor for social cohesion and community continuity.
# - Expected outcomes
#   - A robust, multi-layered defense system; fewer repeated losses; substantial risk-sharing and equitable adaptation.
#
# Decade 5 (Years 41–50): long-term adaptation governance; possible consolidation or withdrawal from high-risk zones
# - Interventions
#   - Maintain and upgrade robust protection measures; ensure NBIs are integrated into city planning as standard infrastructure; monitor for climate-change-driven shifts in hazard distribution.
#   - Social: finalize relocation/retreat programs where necessary; maintain strong social safety nets for displaced populations.
#   - Policy: formalize a long-term resilience fund; create governance that can adapt to new climate realities and population changes.
# - Triggers to reassess mid- to late-century options
#   - If SLR remains high (2.0 m by 2100) and risk distribution remains unfavorable, intensify managed retreat in extremely exposed zones while prioritizing equity and community support.
#   - If SLR is lower, maintain a less aggressive stance and re-evaluate risk targets to protect the urban core while preserving growth opportunities.
#
# (c) Budget allocation and trade-offs under the constraint (10% of city GDP per decade)
# Assumptions used here: city GDP ~ $75B/year; decade budget cap ~ $7.5B. Allocations reflect a balance among NBIs, policy/planning, social programs, and selective structural investments. Budgets shown in rough shares and dollars for clarity; per-decade allocation can be adjusted to the actual GDP trajectory and the SLR scenario.
#
# Overall per-decade allocation (illustrative, mid-range planning)
# - Nature-based and soft infrastructure (NBIs, green-blue corridors, wetlands, dune restoration, urban green infrastructure, water-sensitive urban design): 40–50% of decade budget
#   - dollars (example): $3.0–$3.75B
# - Policy, planning, governance, and social equity programs (land-use updates, building codes, zoning, buyout/relocation programs, affordable housing, insurance subsidies, emergency preparedness): 25–35%
#   - dollars: $1.9–$2.6B
# - Structural and hard infrastructure (critical drainage, pumping, floodwalls, surge barriers, tidal gates) (incremental, scalable, targeted to risk hotspots): 15–25%
#   - dollars: $1.1–$1.9B
# - Operations, maintenance, and contingency (O&M, monitoring, data systems, maintenance of NBIs, reserve fund): 5–10%
#   - dollars: $0.4–$0.75B
# - Contingency and innovation fund (pilot tests, adaptive management, learning-based refinements): 5–10%
#   - dollars: $0.4–$0.75B
#
# Note on differentiation by SLR scenario
# - Low SLR (0.6 m): emphasis remains on NBIs and social programs; structural investments are smaller and tied to demonstrable needs, with maintenance as a primary ongoing cost.
# - Mid SLR (1.2 m): balanced approach; NBIs remain central but additional targeted structural investments in high-risk zones are justified as risk indicators rise.
# - High SLR (2.0 m): early and more substantial NBIs (to avoid costly hard defenses where possible); targeted, prioritized structural investments in only the most critical corridors; intensified buyouts/relocation plans in the most exposed neighborhoods; ensure resilience financing is robust.
#
# ( d ) Expected outcomes under each sea-level scenario
# These are estimates designed to be policy-relevant, not precise predictions. They rely on the planned mix of NBIs, policy measures, social programs, and limited structural investments. They assume disciplined implementation and the presence of triggers that scale interventions as risk grows.
#
# - Low SLR (0.6 m by 2100)
#   - Estimated cumulative lives saved over 50 years: ~80–150 lives
#   - Economic losses avoided (undiscounted): ~$25–40B
#   - Inequality measures: exposure inequality reduced modestly; the relative vulnerability of low-income households declines as NBIs and social programs protect the most exposed; Gini-like exposure index improves by ~0.01–0.04 points
# - Mid SLR (1.2 m by 2100)
#   - Estimated cumulative lives saved: ~60–130 lives
#   - Economic losses avoided: ~$20–50B
#   - Inequality measures: noticeable improvement in equity as protections and subsidies focus on vulnerable neighborhoods; exposure index improvement ~0.02–0.07
# - High SLR (2.0 m by 2100)
#   - Estimated cumulative lives saved: ~40–100 lives
#   - Economic losses avoided: ~$12–60B (heavily dependent on buyouts and relocation effectiveness)
#   - Inequality measures: greater focus on equitable protection; potential for displacement if not carefully managed; exposure index improvement ~0.01–0.05, but with risk of temporary setback if displacement harms social cohesion
#
# Important note on uncertainty
# - These are policy-off results conditioned on timely and well-executed implementation. In all scenarios, the plan aims to maximize resilience and equity, but actual outcomes depend on governance, financing, public acceptance, climate trajectory, and maintenance.
#
# (e) The three most important uncertainties and a prioritized plan to reduce them
# Top uncertainties
# 1) Local SLR trajectory and subsidence (urban-specific amplification of global SLR)
# 2) Effectiveness and durability of nature-based solutions (NBIs) and maintenance costs
# 3) Equity impacts and social acceptance (who benefits, who bears costs, and how displacement is handled)
#
# Plan to reduce uncertainties (prioritized)
# - Uncertainty 1: Local SLR and subsidence
#   - Action: invest in high-resolution monitoring and data collection; deploy LiDAR/topographic surveys; establish a time-series shoreline/land subsidence map; integrate with tidal gauge data and local hydrogeology studies; institute a regularly updated local sea-level rise model with subsidence corrections; run scenario analyses with evolving data.
# - Uncertainty 2: NBIs performance and costs
#   - Action: implement a robust pilot program with controlled experiments (e.g., test different living shoreline designs, maintenance costs, and ecosystem benefits); standardize performance metrics (erosion control, flood attenuation, habitat creation); create a post-implementation monitoring framework; establish a financing plan that includes maintenance contingencies and adaptive management budgets.
# - Uncertainty 3: Equity, social acceptance, and displacement effects
#   - Action: intensify participatory planning with affected communities; measure social indicators (displacement risk, access to services, job security, and housing affordability) and adjust policies accordingly; publish transparent equity metrics; ensure legally protective measures and redress options are in place before large relocations or buyouts; implement independent oversight and community feedback loops.
#
# (f) Three monitoring metrics and thresholds for changing strategy
# - Metric 1: Nuisance flooding frequency in key neighborhoods
#   - Threshold to escalate from soft to structural measures: sustained increase to >60 nuisance-flood days/year in multiple neighborhoods for two consecutive years, or a rising 3-year moving average trend (significant, persistent increase).
# - Metric 2: Shoreline retreat rate at critical transects
#   - Threshold to escalate: retreat rate exceeding 0.3–0.5 m/year for two consecutive measurement cycles; if proprietary sensors indicate acceleration due to subsidence or maintenance shortfalls, adjust plan immediately.
# - Metric 3: Insurance and financial signals
#   - Threshold to escalate: private insurers withdraw or raise premiums by >20% year-over-year for two consecutive years; or the city experiences a material increase in uninsured exposure or failure of coverage on essential properties; triggers a shift from NBIs to targeted structural investments and enhanced social protection.
#
# (g) Three ethically contentious decisions and rationale
# 1) Managed retreat in high-risk neighborhoods
# - Why this choice: reduces long-term risk to residents and city budgets; but threatens home ownership, neighborhood fabric, and cultural ties.
# - How to communicate and mitigate harms: ensure voluntary participation, strong housing options, fair compensation, job relocation assistance, and robust social programs; provide meaningful community engagement, transparent criteria, and ensure no forced displacements without consent.
# 2) Differential investment by neighborhood (prioritize protection for lower-income areas or critical service hubs)
# - Why this choice: aligns protection with vulnerability and ensures essential services; risk of perceived inequity or “favoring some neighborhoods over others.”
# - How to communicate and mitigate harms: implement a transparent, needs-based scoring system; publish district-level risk and resilience profiles; ensure that all communities see long-term benefits and have clear paths to participate in decision-making.
# 3) Buyouts and long-term relocation programs
# - Why this choice: may be the most sustainable long-term option for some neighborhoods facing chronic risk; raises concerns about community disruption and affordable housing in destination neighborhoods.
# - How to communicate and mitigate harms: ensure fair compensation, preserve social networks and access to livelihoods, provide relocation assistance, and ensure replacement housing options meet affordability and proximity to jobs; maintain ongoing community engagement and post-relocation supports.
#
# (Ways to communicate and mitigate harms)
# - Public participation: early and ongoing community engagement; accessible information; multilingual communications.
# - Equity safeguards: ensure that vulnerable groups receive targeted assistance; track and publish equity indicators.
# - Transparency and accountability: independent oversight; public dashboards showing cost, risk reduction, and social outcomes.
# - Compensation and support: financial support, job training, and housing options that minimize disruption to livelihoods and social networks.
#
# ( h ) Strategy critique: three plausible failure modes, earliest warning signs, and contingency actions
# 1) Failure mode: underfunding or delayed financing prevents roll-out of critical NBIs and social protections
# - Early warning signs: rising maintenance backlogs; inability to deliver planned retrofits on schedule; public sentiment shifts toward questioning the value of resilience investments.
# - Contingency actions: activate reserve funds; pursue emergency bridging finance (climate resilience bonds); reprioritize projects toward highest-risk zones; seek state/federal grants or public-private partnerships to accelerate delivery; fast-track pay-as-you-go measures for high-ROI NBIs.
# 2) Failure mode: ineffective community engagement leading to low adoption of expensive measures or displacement backlash
# - Early warning signs: neighborhood opposition, rumors about eminent domain, or protests against relocation plans; lagging uptake of retrofit subsidies or insurance programs.
# - Contingency actions: pause contentious elements, broaden stakeholder engagement, co-design solutions with communities, adopt more voluntary and culturally sensitive approaches, and implement stronger economic and social protections for affected households.
# 3) Failure mode: decision inertia and political turnover undermining long-term resilience governance
# - Early warning signs: frequent policy reversals, inconsistent funding, and uncertain management structures; erosion of cross-agency collaboration.
# - Contingency actions: establish independent resilience authority or permanent cross-departmental governance body; enshrine core resilience objectives in city charter or enduring legislative framework; lock in funding streams via long-term bonds and dedicated reserves; create public accountability mechanisms (annual resilience report, citizen oversight).
#
# Final notes and practicalities
# - The proposed strategy is designed to be resilient to a wide range of SLR outcomes (low, mid, high) and takes into account the city’s budget constraint. It emphasizes equity and social protection for low-income residents and communities most at risk.
# - It is important to maintain a robust monitoring program (physical sensors, wetland health, shoreline mapping, socio-economic indicators) and to update the plan periodically in light of new data, changing climate conditions, and community feedback.
# - Success hinges on transparent governance, credible financing, and continuous community engagement. If managed well, the plan can substantially reduce risk, protect lives and livelihoods, and improve city resilience and quality of life under all SLR scenarios.
#
# If you’d like, I can convert this into a formal 50-year program document with costed line items, explicit annual budgets per department, and a risk register.
#
# # Response from competitor 2
#
# **Adaptation Strategy (50-year plan)**
#
# **Prioritization Framework**
#
# 1. Structural interventions prioritize sea wall construction, dune restoration, and flood gate installations.
# 2. Policy interventions focus on zoning regulations, building codes, and infrastructure upgrades.
# 3. Social programs target vulnerable populations with financial assistance, relocation support, and education.
# 4. Nature-based solutions emphasize green infrastructure development.
#
# **Decade-by-Decade Timeline**
#
# 1. 2025-2030:
# 	* Trigger: Increasing frequency of nuisance flooding (<5 events/decimal).
# 	* Interventions: Implement urban drainage system upgrades (Policy).
# 2. 2030-2035:
# 	* Trigger: Shoreline retreat rate increases to 0.1 m/decade.
# 	* Interventions: Start dune restoration and beach nourishment programs (Nature-based, Policy).
# 3. 2035-2040:
# 	* Trigger: Insurance cost increases by >2%.
# 	* Interventions: Construct moderate sea walls (<1m) in high-risk areas (Structural, Policy).
# 4. 2040-2045:
# 	* Trigger: Sea-level rise projections converge to >1.5 m.
# 	* Interventions: Initiate full-scale sea wall construction and floodgate installations (Structural).
# 	* Differential investment by neighborhood considered for extreme risk zones.
#
# **Budget Allocation**
#
# * Total budget constraint: 10% of current city GDP / decade.
# * Allocating 60% to Structural interventions, 20% to Policy strategies, 15% to Social programs, and 5% to Nature-based solutions.
#
# **Expected Outcomes (2100 Scenarios)**
#
# 1. Low Sea-Level Rise (0.6 m): Estimated:
# 	+ Lives saved: 100
# 	+ Economic losses avoided: $1 billion
# 	+ Reduced inequality measure: 2%
# 2. Mid-Sea-Level Rise (1.2 m): Estimated:
# 	+ Lives saved: 500
# 	+ Economic losses avoided: $10 billion
# 	+ Reduced inequality measure: 6%
# 3. High Sea-Level Rise (2.0 m): Estimated:
# 	+ Lives saved: 1,000
# 	+ Economic losses avoided: $50 billion
# 	+ Reduced inequality measure: 12%
#
# **Uncertainties**
#
# 1. Scientific uncertainty:
#  * Mitigation plan: Develop advanced coastal monitoring systems and perform detailed risk assessments for urban areas.
# 2. Economic uncertainty:
#  + Mitigation plan: Monitor economic performance closely, adapting business strategies to minimize losses when faced with increased flooding.
# 3. Social uncertainty:
#  + Mitigation plan: Prioritize public engagement, fostering inclusivity in decision-making processes for residents.
#
# **Monitoring Metrics and Thresholds**
#
# 1. Frequency of Nuisance Flooding: >5 events/decade (Trigger 2025-2030).
# 2. Shoreline Retreat Rate: >0.15 m/decade (Trigger 2030-2040).
# 3. Insurance Cost Increases: >3% annually.
#
# **Ethically Controversial Decisions**
#
# 1. **Managed Retreat**: A section designated for planned sinking and relocation.
#    - Justifies implementation over public education campaigns, aiming to preserve critical infrastructure and urban spaces.
#    - Effective mitigation involves transparent dialogue and support networks for residents impacted by the decision.
#
# 2. Differential investment by Neighborhoood for extreme risk zones:
#    Prioritize targeted investments addressing heightened flood risks while offering equitable benefits to the affected communities.
#    To mitigate potential disparity: Implement a participatory, evidence-based development plan ensuring representation from both the benefited community members and their needs within broader policy decisions.
#
# 3. Selective displacement strategy:
# To accommodate residents at risk of being displaced without sacrificing urban areas.
# - Facilitate inclusive communication with residents regarding available options, including relocation support services and financial compensation or alternatives like rehousements to neighboring properties.
# - Manage concerns by transparently planning community projects to minimize loss of social unity and preserve the sense of home.
#
# **Failure Modes and Contingency Actions**
#
# 1. **Increased insurance costs over projected levels**: Adapt budgetary allocation as per revised projections, ensuring continuous spending meets constraints while optimizing outcomes through targeted risk mitigation strategies.
#
# 2. Impact from underestimating projected sea-level rise: Implement early, multi-decade scale-up of urban planning measures to effectively protect infrastructure in anticipation of higher-than-expected rates.
#
# 3. Failure in monitoring effectiveness or oversight leading to inadequate timely interventions:
# Adapt communication channels and strategic planning methodologies regularly to keep community members updated on their safety expectations regarding rising sea levels through the city's adaptation policy guidance.
#    - Use cutting-edge data analytics tools and involve more localized residents during decision-making phases for better outcomes.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "2"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-5-nano
# Rank 2: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
